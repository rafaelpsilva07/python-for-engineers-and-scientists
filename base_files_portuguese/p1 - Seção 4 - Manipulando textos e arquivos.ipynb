# %% [markdown]
# # Desenvolvimento de Pacotes Científicos com Python
#
# **por**: Rafael Pereira da Silva

# %% [markdown]
# # PARTE 1
# # Seção 4: Manipulando textos e arquivos

# %% [markdown]
# ## 4.1 - Operações com strings
#
# <br/>
#
# Algumas características das strings são:
# - [x] Aceitam operações da matemática
# - [x] São indexáveis (slicing)
# - [x] São iteráveis
# - [x] Aceitam formatações especiais
# - [x] (\\) barras são utilizados em casos especiais

# %% [markdown]
# ## 4.2 - Métodos para strings
#
# <br/>
#
# **Alguns métodos de manipulação de strings:**
#
# <br/>
#
# | Método | Descrição |
# | :-- | :-- |
# | upper() | Retorna letras maiúsculas |
# | lower() | Retorna letras minúsculas |
# | replace(arg_ant, arg_nov) | Substiuí arg_ant pelo arg_nov  |
# | find(arg)| Retorna a posição da primeira ocorrencia. Olhe: rfind() |
# | strip() | Retorna um string removendo caracteres em branco do início e do fim. Olhe: rstrip(), lstrip() |
# | count() | Retorna o número de ocorrências de item. |
# | split(arg) | Retorna uma lista onde os elementos são separados pelo argumento de entrada |
# | isupper() | Checa se todas as letras são maiúsculas e retorna um booleano. Olhe: islower(), isalpha(), isnumeric() |
# | startswith(arg) | Checa se a string começa com arg. Olhe: endswith() |
#
#
# <br/>
#
# **nota:**
# <pre>É sempre importante checar como o método que você está utilizando age sobre o objeto. Neste caso os métodos não modificam o objetos, pois strings são imutáveis.</pre>

# %% [markdown]
# ## 4.3 - Formatação para strings
#
# <br/>
#
# A partir do python 3.6, foram adicionados as *f-strings* que facilitam a formatação dos strings. Caso você esteja utilizando uma versão de python anterior, há outras maneiras de fazer a formatação de string como o método format() ou o %.
#
# <br/>
#
# #### Sintaxe do f'string
#
# ```python
# >>> resultado = 10
# >>> texto_resultado = f'resultado = {resultado}'
# >>> pi = 3.14159
# >>> valor_pi = f'O valor de pi é {pi: .2f}'
# ```
#
# <br/>
#
# **nota:**
# <pre>Além do f'string, há outros prefixos que podem serem utilizados: r para raw (bruto), b para binários e u para unicode. </pre>

# %% [markdown]
# ## 4.4 - Lendo e escrevendo arquivos
#
# <br/>
#
# Ler e escrever arquivos é uma ótima forma de automatizar tarefas na ciência e na engenharia. No entanto, devemos fazer isso da forma correta para não mantermos o arquivo aberto sem sabermos. Para não correr esse risco, use o statement **with**.
#
# #### Sintaxe do f'string
#
# ```python
# >>> path = 'C:/....'
# >>> with open(path, 'r') as f:
# >>>     conteudo = f.read()
# >>> print(conteudo)
# ```
#
# **notas:**
#
# <pre>Parâmetros:
# - 'r': read (ou leitura)
# - 'w': write (escrita)
# - 'wb': write binary (escrita binária)</pre>
#
# <pre>Métodos:
# - read(): lê o conteúdo do arquivo e retorna uma string
# - readlines(): lê o conteúdo do arquivo e retorna uma lista </pre>

# %%
path = 'D:/repositories/notebooks/\
1-Python para Engenheiros e Cientistas - Professional/auxiliary_files/'

with open(path + 'fileToRead.txt', 'r', encoding="utf-8") as f:
    #content = f.read()
    content_line_by_line = f.readlines()

# %%
print(content_line_by_line)
# Out:
# ['Olá mundo\n', 'Eu sou Rafael\n', 'Sejam bem vindo ao Engenharia Refinada']

# %%
new_content = 'Este arquivo será escrito via Python \n\
Faremos em utf-8, pois contém acentos \n\
Grande abraço a todos!'

with open(path + 'fileToWrite', 'w', encoding="utf-8") as f:
    #content = f.read()
    f.write(new_content)

# %% [markdown]
# ## 4.5 - Encoding
#
# <br/>
#
# De forma simples, o encoding, ou codigicação de caracteres, é uma tabela de conversão de formato binário em um formato de texto.
#
# <br/>
#
# #### Exemplos
#
# | UTF-8 | ANSI | ASCII | character |
# | -:- | -:- | -:- | -:- |
# | 01000001 (41) | 01000001   | 01000001 | A |
# | 01011010 (5A) | 01011010 | 01011010 | Z |
# | 01100001 (61) | 01100001 | 01100001 | a |
# | 01111010 (7A)| 01111010 | 01111010 | z |
# | 11000011 10100001 (C3 A1) | 11100001 (E1)| -- | á |
# | 11000011 10000001 (C3 81)| 11000001 ( C1)| -- | Á |
#
# <br/>
#
# **nota:**
# <pre>ASCII é formado com 1 byte (8 bits), sendo que o primeiro número não é utilizado, portanto a tabela possui 128 valores. Essa tabela não possui acentos </pre>
# <pre>ANSI é formado com 1 byte (8 bits), ela possui 256 valores. Contém todos aqueles do ASCII e mais outros incluindo acentos </pre>
# <pre>O UTF-8 utiliza um conceito multibytes. Os primeiros 128 caracteres são do ASCII. A medida que há demanda por caracteres especiais, mais bytes são incluídos. O consórcio do UTF-8 contém mais de um milhão de caracteres e alguns deles podem chegar a 3 bytes. </pre>
#
# <br/>
#
# **Referências:**
#
# https://www.gaijin.at/en/infos/unicode-character-table-latin
#
# https://www.gaijin.at/en/infos/ascii-ansi-character-table
#
# https://www.ime.usp.br/~pf/algoritmos/apend/unicode.html

# %%
def binaryToDecimal(n):
    return int(n, 2)

# %%
hex(binaryToDecimal('10000001'))
# Out:
# '0x81'

# %%
a = 'á'

a.encode(encoding='UTF-8')
# Out:
# b'\xc3\xa1'

# %% [markdown]
# # Exercícios

# %% [markdown]
# ## E4.1
# Dado um email qualquer, ```exemplo@gmail.com```, retorne uma lista com o nome de usuário e o domínio.
#
# Saída:
#
# ```
# [exemplo, gmail]
# ```

# %%
email = 'rafael@gmail.com'
a, b = email.split('@')

# %%
def split_email(email):
    login, dominio = email.split('@')
    dominio, *_ = dominio.split('.')
    result = [login, dominio]
    return result

# %%
split_email(email)
# Out:
# ['rafael', 'gmail']

# %% [markdown]
# ## E4.2
# Dado um arquivo com emails, retorne uma lista com os logins e com os domínios.
#
# Formato de dados sugerido:
# ```python
# lista_emails = [[login1, dominio1],
#                 [login2, dominio2],
#                 [loginn, dominion]
#                ]
# ```

# %%
emails_path = 'D:/repositories/notebooks/1-Python para Engenheiros e Cientistas - Professional/auxiliary_files/'

with open(emails_path + 'emails.txt', 'r') as file:
    conteudo = file.readlines()

# %%
resposta = []

for i in conteudo:
    resposta.append(
        split_email(i)
    )

# %%
resposta
# Out:
# [['a3sign', 'pandora'],
#  ['aaanika2', 'hotmail'],
#  ['aaron2003s', 'bol'],
#  ['aaron--21', 'hotmail'],
#  ['abidoral', 'hotmail'],
#  ['abk_333', 'hotmail'],
#  ['abner_bim', 'hotmail'],
#  ['abner_bim', 'hotmail'],
#  ['acacio_divix', 'hotmail'],
#  ['academia.boaforma', 'yahoo'],
#  ['ac-ferian', 'bol'],
#  ['acordarsono', 'hotmail'],
#  ['acsa_lim', 'yahoo'],
#  ['adamyth', 'gmail'],
#  ['add_ae_jente', 'yahoo'],
#  ['addgeral', 'gmail'],
#  ['addyevusk', 'yahoo'],
#  ['adeozemir', 'yahoo'],
#  ['adhaha', 'gmail'],
#  ['adhaha', 'gmail'],
#  ['adidas__star', 'hotmail'],
#  ['adidas__star', 'hotmail'],
#  ['adilio-vidaloka', 'yahoo'],
#  ['adilson.mariano5', 'terra'],
#  ['admgerald1', 'yahoo'],
#  ['adri_barboza', 'hotmail'],
#  ['adri_barboza', 'hotmail'],
#  ['adriaens', 'pandora'],
#  ['adrian_boyzinhu', 'yahoo'],
#  ['adriana_lemes_farias', 'hotmail'],
#  ['adriana_lemes_farias', 'hotmail'],
#  ['adrianacpx', 'yahoo'],
#  ['adriane_do_prado', 'yahoo'],
#  ['adrianinhaim', 'bol'],
#  ['adrianinhaim', 'bol'],
#  ['adrianinhaxp', 'yahoo'],
#  ['adriano.fariasnascimento', 'yahoo'],
#  ['adriano_wolf1', 'hotmail'],
#  ['adrianogato.2007', 'hotmail'],
#  ['adrianojareck', 'hotmail'],
#  ['adrianonev3s', 'gmail'],
#  ['adrianosenna', 'yahoo'],
#  ['adrianraniery', 'bol'],
#  ['Adriedson88', 'hotmail'],
#  ['adrieli_baldoria', 'hotmail'],
#  ['adrielle_amaral', 'yahoo'],
#  ['adrielli_cr', 'hotmail'],
#  ['adrielly', 'yaroo'],
#  ['adrielly_silva', 'yaroo'],
#  ['adriely_94', 'hotmail'],
#  ['adrienevinhote', 'hotmail'],
#  ['adryana_maia', 'hotmail'],
#  ['adryana_maia', 'hotmail'],
#  ['adryana_maia', 'hotmail'],
#  ['adryshevchenko7', 'hotmail'],
#  ['adryshevchenko7', 'yahoo'],
#  ['adryshevchenko7', 'hotmail'],
#  ['a-ferraz', 'bol'],
#  ['afonso-catador', 'hotmail'],
#  ['afonso-catador', 'hotmail'],
#  ['afonsoducarmo', 'yahoo'],
#  ['afrancar15', 'yahoo'],
#  ['agatha_rosa8', 'yahoo'],
#  ['agatha_rosa8', 'yahoo'],
#  ['agente_fbi13', 'yahoo'],
#  ['agente_fbi13', 'yahoo'],
#  ['agente_fbi13', 'yahoo'],
#  ['agloco.com.fake', 'gmail'],
#  ['agloco-sv', 'bol'],
#  ['agnaldojt', 'hotmail'],
#  ['agoraeuvodetona2', 'yahoo'],
#  ['agoraeuvodetona2', 'yahoo'],
#  ['agricesar', 'yahoo'],
#  ['agricesar', 'yahoo'],
#  ['agricesar', 'yahoo'],
#  ['aguia_fenix', 'hotmail'],
#  ['aguinaldo4789', 'hotmail'],
#  ['aguinaldo4789', 'hotmail'],
#  ['aguinaldo4789', 'hotmail'],
#  ['ai_', 'hotmail'],
#  ['Aiacos.Kyoto', 'gmail'],
#  ['aim.vip2', 'hotmail'],
#  ['aim.vip25', 'hotmail'],
#  ['aiopam', 'hotmail'],
#  ['aislyn14', 'yahoo'],
#  ['aislyn14', 'yahoo'],
#  ['ajudasystemonline', 'gmail'],
#  ['ajuding.01', 'hotmail'],
#  ['akitanajura', 'yahoo'],
#  ['akitanajura', 'yahoo'],
#  ['ala-frei', 'hotmail'],
#  ['alahfilho', 'gmail'],
#  ['alan_gatinho_sjc', 'yahoo'],
#  ['alan_kiedis2', 'yahoo'],
#  ['alan_morenogato', 'hotmail'],
#  ['alan_schmeiske', 'hotmail'],
#  ['alandenissouza', 'hotmail'],
#  ['alanfarias_18', 'yahoo'],
#  ['alaninha_13', 'hotmail'],
#  ['alanjonny_rp89', 'hotmail'],
#  ['alanjonny_rp89', 'hotmail'],
#  ['alanmoreira12', 'yahoo'],
#  ['Alanvitim', 'yahoo'],
#  ['alanyseyes', 'msn'],
#  ['alanzin.mel', 'hotmail'],
#  ['alareskamartins', 'hotmail'],
#  ['albinorios2', 'hotmail'],
#  ['albinorios2', 'hotmail'],
#  ['aldy.serg', 'uol'],
#  ['ale_amor05', 'hotmail'],
#  ['ale_amor05', 'hotmail'],
#  ['ale_amor05', 'hotmail'],
#  ['ale_amor05', 'hotmail'],
#  ['ale_zinha_hta', 'hotmail'],
#  ['aleckis_97', 'hotmail'],
#  ['aleckis_97', 'hotmail'],
#  ['aleckis_97', 'hotmail'],
#  ['aledickinsooon', 'hotmail'],
#  ['alef_saopaulo', 'yahoo'],
#  ['alemao_alison', 'hotmail'],
#  ['Aleson_pml', 'yahoo'],
#  ['aless_pina25', 'hotmail'],
#  ['alessandrabrittosouza', 'gmail'],
#  ['alessandralazarini', 'yahoo'],
#  ['alessandranyzewski', 'yahoo'],
#  ['alessandrofortuna1', 'hotmail'],
#  ['alex.3carlos', 'yahoo'],
#  ['alex_betalia', 'hotmail'],
#  ['alex_betalia', 'hotmail'],
#  ['alex_farkas', 'hotmail'],
#  ['alex_llk', 'yahoo'],
#  ['ALEX91BADBOY', 'YAHOO'],
#  ['ALEX91BADBOY', 'YAHOO'],
#  ['ALEX91BADBOY', 'YAHOO'],
#  ['alexandra_assaf', 'hotmail'],
#  ['alexandra_praca', 'hotmail'],
#  ['alexandre.audi', 'uol'],
#  ['alexandre.carreiro', 'gmail'],
#  ['alexandre.goes', 'hotmail'],
#  ['alexandre.stoian2', 'gmail'],
#  ['alexandreairtonreisteles', 'yahoo'],
#  ['alexandrecachapus', 'yahoo'],
#  ['alexandressmelo', 'hotmail'],
#  ['alexandretormen', 'hotmail'],
#  ['alexandretormen', 'hotmail'],
#  ['alexandrinho_tdb64', 'yahoo'],
#  ['alexandrino.thiago', 'gmail'],
#  ['alexbegins', 'hotmail'],
#  ['alexcabeludo2', 'hotmail'],
#  ['alexcabeludo2', 'hotmail'],
#  ['alexd3', 'gmail'],
#  ['alexfonsek', 'yahoo'],
#  ['alexmendesskt', 'yahoo'],
#  ['alexrdgs.89', 'gmail'],
#  ['alexrosa55', 'yahoo'],
#  ['alexsandro004', 'uol'],
#  ['alexsandrotavares', 'msn'],
#  ['alextsm10', 'yahoo'],
#  ['alexwaldo', 'globo'],
#  ['alfonsogatto10000', 'hotmail'],
#  ['alfredochallco', 'bol'],
#  ['algmjaescolheuessenomedeusuario', 'yahoo'],
#  ['ALI.SILVA', 'HOTMAIL'],
#  ['alice_xmedeiros', 'yahoo'],
#  ['aline.moretti.sanches', 'gmail'],
#  ['aline.moretti.sanches', 'gmail'],
#  ['aline.rickmann', 'ig'],
#  ['aline__patty', 'hotmail'],
#  ['aline_aquino', 'oi'],
#  ['aline_boladona2006', 'hotmail'],
#  ['aline_gatinha_13', 'yahoo'],
#  ['aline_rbd_rx', 'hotmail'],
#  ['aline_reggae13', 'hotmail'],
#  ['aline_reggae13', 'hotmail'],
#  ['aline_sakuray', 'hotmail'],
#  ['aline_somg', 'hotmail'],
#  ['aline-150793', 'hotmail'],
#  ['alinealg', 'yahoo'],
#  ['alinebmb', 'gmail'],
#  ['alinecordeiro_17', 'hotmail'],
#  ['alinecordeiro_17', 'hotmail'],
#  ['alinedaniele_14', 'yahoo'],
#  ['alinedantas4', 'gmail'],
#  ['alineferreira_01', 'yahoo'],
#  ['alinegcanta', 'hotmail'],
#  ['alinegirl_49', 'hotmail'],
#  ['alineilima', 'hotmail'],
#  ['alinejaque', 'gmail'],
#  ['alinejaque', 'gmail'],
#  ['alinenewjersey', 'msn'],
#  ['alinenj_usa', 'yahoo'],
#  ['alineoliveiraes', 'gmail'],
#  ['alineteacher', 'yahoo'],
#  ['alineteacher', 'yahoo'],
#  ['alinewolff', 'hotmail'],
#  ['alininhaderaul', 'yahoo'],
#  ['alininhaderaul', 'yahoo'],
#  ['alinyfereira', 'yahoo'],
#  ['alisson.marquessss', 'gmail'],
#  ['alisson.marquessss', 'gmail'],
#  ['allan.teodoro', 'gmail'],
#  ['allan_17_1309', 'hotmail'],
#  ['allan_17_1309', 'hotmail'],
#  ['allanbraga11', 'hotmail'],
#  ['allancalipio', 'bol'],
#  ['allannynhah_15', 'hotmail'],
#  ['allansilvasouza', 'hotmail'],
#  ['allansisti', 'hotmail'],
#  ['allex_pe', 'hotmail'],
#  ['allysson.camillo', 'Gmail'],
#  ['allyssoncachorroloko', 'hotmail'],
#  ['alonsomaria', 'bol'],
#  ['alonsomaria', 'bol'],
#  ['altamirfilho', 'gmail'],
#  ['altamirfilho', 'gmail'],
#  ['altamirfilho', 'gmail'],
#  ['aluapinh', 'yahoo'],
#  ['alvaro_borges', 'hotmail'],
#  ['alvarovallecamargos', 'yahoo'],
#  ['alyne_ns', 'hotmail'],
#  ['amanda.kell', 'yahoo'],
#  ['amanda-_lima', 'hotmail'],
#  ['amanda_rribeiro', 'hotmail'],
#  ['amanda_rribeiro', 'hotmail'],
#  ['amanda_rribeiro', 'hotmail'],
#  ['amandadosreiscardozo', 'hotmail'],
#  ['amandakell', 'uol'],
#  ['amandalenzpszybilski14', 'yahoo'],
#  ['amandamedeiros22', 'hotmail'],
#  ['amandanayara_nana', 'hotmail'],
#  ['amandapriscila_bq', 'yahoo'],
#  ['amandaroveri', 'hotmail'],
#  ['amandaroveri', 'hotmail'],
#  ['amandasantos_cruz', 'hotmail'],
#  ['amandashirmay', 'hotmail'],
#  ['amandasmith748', 'hotmail'],
#  ['amandha1993', 'hotmail'],
#  ['amandinha_pink12', 'hotmail'],
#  ['amandinha160', 'hotmail'],
#  ['amandinhah_princess', 'msn'],
#  ['amandinhalinda96', 'hotmail'],
#  ['amandinhaop', 'gmail'],
#  ['amardita', 'gmail'],
#  ['amarlivrementeamar', 'hotmail'],
#  ['amauri_file', 'hotmail'],
#  ['amaury_css', 'hotmail'],
#  ['amavel_ds', 'yahoo'],
#  ['amdkell', 'gmail'],
#  ['ameliacunha2', 'yahoo'],
#  ['ameliacunha2', 'yahoo'],
#  ['ameliacunha2', 'yahoo'],
#  ['ammoal', 'bol'],
#  ['amo_amandakell', 'hotmail'],
#  ['amorebeldedemais', 'bol'],
#  ['ana.lacerda', 'bol'],
#  ['ana.lacerda', 'bol'],
#  ['ana.laura.zimmermann', 'hotmail'],
#  ['ana.paula.vargas', 'hotmail'],
#  ['ana.poc', 'hotmail'],
#  ['ana_12karla', 'hotmail'],
#  ['ana_ana_15', 'live'],
#  ['ana_carolmonteiro', 'hotmail'],
#  ['ana_doidoina', 'hotmail'],
#  ['ana_isabel153', 'hotmail'],
#  ['ana_jac_16', 'hotmail'],
#  ['ana_paula_santos', 'msn'],
#  ['ana_pr_amaral', 'hotmail'],
#  ['ana_stek', 'hotmail'],
#  ['anacarolinapek', 'hotmail'],
#  ['anacarolinapek', 'hotmail'],
#  ['anaclaudia_faria01', 'yahoo'],
#  ['anadpra', 'yahoo'],
#  ['anadpra', 'yahoo'],
#  ['Anaflavinhab', 'yahoo'],
#  ['Anaflavinhab', 'yahoo'],
#  ['anagatinha_msn', 'hotmail'],
#  ['anahxc', 'hotmail'],
#  ['analimabittencourt', 'gmail'],
#  ['analuizanascimento', 'bol'],
#  ['analyne_divercao', 'yahoo'],
#  ['ananda.sampaio', 'hotmail'],
#  ['anandinhay_', 'hotmail'],
#  ['anandinhay_', 'hotmail'],
#  ['anao_psl', 'hotmail'],
#  ['anap_gatinha_2007', 'yahoo'],
#  ['anapaula-orkut', 'hotmail'],
#  ['anapaulapereira_15', 'yahoo'],
#  ['anapaulapereira_15', 'yahoo'],
#  ['anapaulapereira_15', 'yahoo'],
#  ['anapaullaqueiroz', 'hotmail'],
#  ['anapaullaqueiroz', 'hotmail'],
#  ['anapaullaqueiroz', 'hotmail'],
#  ['anaptbombig', 'bol'],
#  ['anas2s2dasilva', 'bol'],
#  ['anascholl64', 'hotmail'],
#  ['anaselenem', 'yahoo'],
#  ['anaselenem', 'yahoo'],
#  ['anaselenem', 'yahoo'],
#  ['anasilva_alice', 'hotmail'],
#  ['and.justice.for.all', 'bol'],
#  ['ande_cobo', 'hotmail'],
#  ['ander_peu', 'hotmail'],
#  ['andersomzinhu', 'bol'],
#  ['anderson.afsd', 'gmail'],
#  ['anderson.afsd', 'gmail'],
#  ['anderson.afsd', 'gmail'],
#  ['anderson.psirico', 'yahoo'],
#  ['anderson.s30', 'gmail'],
#  ['anderson_fersilva', 'yahoo'],
#  ['anderson_ups', 'yahoo'],
#  ['andersonaraujob', 'gmail'],
#  ['andersonbeliene3', 'gmail'],
#  ['andersondoopala', 'hotmail'],
#  ['andersongara', 'yahoo'],
#  ['anderson-plasma', 'bol'],
#  ['andersonsapolandia', 'gmail'],
#  ['andersonsc182', 'yahoo'],
#  ['anderson-sephiroth', 'hotmail'],
#  ['andhesa', 'bol'],
#  ['andinhoufrn', 'hotmail'],
#  ['andradenego', 'yahoo'],
#  ['andre.floripas2', 'yahoo'],
#  ['andre.rodolfo', 'ig'],
#  ['andre.vincius', 'gmail'],
#  ['andre.vincius', 'gmail'],
#  ['andre.vincius', 'gmail'],
#  ['andre.vincius', 'gmail'],
#  ['andre_massot', 'ig'],
#  ['andre_pitbulldoidera', 'yahoo'],
#  ['andre_pitbulldoidera', 'yahoo'],
#  ['andre_pitbulldoidera', 'yahoo'],
#  ['andre_ritt', 'hotmail'],
#  ['andrea_araujo_br', 'yahoo'],
#  ['andrea_fatima2005', 'hotmail'],
#  ['andrea_fatima2005', 'hotmail'],
#  ['andreasalles_12', 'hotmail'],
#  ['andreasinnott', 'bol'],
#  ['andrebarbosa28', 'yahoo'],
#  ['andrebits', 'bol'],
#  ['andrebrownbiologia', 'oi'],
#  ['andrecampos87', 'bol'],
#  ['andrechsian', 'bol'],
#  ['andrechumbim', 'yahoo'],
#  ['andrechumbim', 'yahoo'],
#  ['andrechumbim', 'yahoo'],
#  ['andredemais', 'gmail'],
#  ['andreiaregina_po', 'hotmail'],
#  ['andreiaregina_po', 'hotmail'],
#  ['andreiaregina_po', 'hotmail'],
#  ['andreinha2007', 'hotmail'],
#  ['andrel.xavier', 'yahoo'],
#  ['andreluis_4499', 'hotmail'],
#  ['andreluizgodoi', 'hotmail'],
#  ['andremarques_vieira', 'yahoo'],
#  ['andremeleite', 'gmail'],
#  ['andrentfsowner', 'gmail'],
#  ['andrentfsowner', 'gmail'],
#  ['andresaopaulo2005', 'yahoo'],
#  ['andressa.silva1994', 'bol'],
#  ['andressa_galeazzi', 'hotmail'],
#  ['andressa_hhh', 'hotmail'],
#  ['andressafigura', 'yahoo'],
#  ['andressasrhta', 'hotmail'],
#  ['andretolentino262', 'hotmail'],
#  ['andretolentino262', 'hotmail'],
#  ['andretolentino262', 'hotmail'],
#  ['andrevieiramonteiro', 'ibest'],
#  ['andreza_badgirl', 'zipmail'],
#  ['Andreza_mdm_', 'hotmail'],
#  ['andrezapollo', 'bol'],
#  ['andrezinhu.cs', 'bol'],
#  ['aneliza_gatinha_12', 'hotmail'],
#  ['anewragtiwari', 'gmail'],
#  ['angeel_4', 'hotmail'],
#  ['angel_vick_fake', 'yahoo'],
#  ['angela_jah', 'hotmail'],
#  ['angela_jah', 'hotmail'],
#  ['angela_jah', 'hotmail'],
#  ['angela_raimann', 'yahoo'],
#  ['angelica.lucidia', 'gmail'],
#  ['angelicaaltoe2', 'gmail'],
#  ['angelical-cat17', 'hotmail'],
#  ['angelicawonderful', 'yahoo'],
#  ['angellouquinha', 'bol'],
#  ['angelo647', 'hotmail'],
#  ['Angelofmelo', 'portalcorinthians'],
#  ['Angelofmelo', 'portalcorinthians'],
#  ['Angelofmelo', 'portalcorinthians'],
#  ['angel-perfect18', 'bol'],
#  ['anielrte', 'hotmail'],
#  ['anielsath', 'gmail'],
#  ['anielsath', 'gmail'],
#  ['anielsath', 'gmail'],
#  ['anielsath2', 'gmail'],
#  ['anielsath2', 'gmail'],
#  ['anika_', 'uol'],
#  ['aninha_aas', 'yahoo'],
#  ['aninha_aas', 'yahoo'],
#  ['aninha_benfica', 'hotmail'],
#  ['aninha_breezy3vax', 'yahoo'],
#  ['aninha183', 'hotmail'],
#  ['aninhaa.cmo', 'gmail'],
#  ['aninhacordeiro', 'yahoo'],
#  ['aninhagataloira', 'gmail'],
#  ['aninha-gd-punk', 'bol'],
#  ['aninhap.11', 'hotmail'],
#  ['aninhapaulinha88', 'yahoo'],
#  ['aniram_life', 'hotmail'],
#  ['aniram_life', 'hotmail'],
#  ['aniram_life', 'hotmail'],
#  ['anjodomal_cs', 'hotmail'],
#  ['anjogabrielresolve', 'yahoo'],
#  ['anjometal5', 'gmail'],
#  ['anjonegroo', 'yahoo'],
#  ['anjonick', 'hotmail'],
#  ['anjorafaell21', 'yahoo'],
#  ['anjosssssssss', 'yahoo'],
#  ['Anna_criistina', 'hotmail'],
#  ['annakeile', 'yahoo'],
#  ['annemievandevloed', 'pandora'],
#  ['anninhakalil', 'hotmail'],
#  ['annyhtona_', 'hotmail'],
#  ['annyjapa', 'gmail'],
#  ['annynhacarol123', 'hotmail'],
#  ['annynhacarol123', 'hotmail'],
#  ['annynhacarol123', 'hotmail'],
#  ['annynicegirl', 'hotmail'],
#  ['anonimo_add9', 'yahoo'],
#  ['anonimo_bbb7', 'hotmail'],
#  ['anonimo_nonu', 'yahoo'],
#  ['antonia_gauchinha', 'yahoo'],
#  ['antonio-tato18', 'bol'],
#  ['antwantheswan', 'bol'],
#  ['anynha_k3', 'hotmail'],
#  ['anynha_marin', 'hotmail'],
#  ['anyyzuda', 'hotmail'],
#  ['anyzeenha', 'yahoo'],
#  ['apbj_hata', 'hotmail'],
#  ['apenaspruorkutdofer', 'hotmail'],
#  ['apgfanap', 'hotmail'],
#  ['apgfanap', 'hotmail'],
#  ['apolo_deusdosol', 'hotmail'],
#  ['aprivada2025', 'yahoo'],
#  ['apsspoderosa', 'hotmail'],
#  ['apsspoderosa', 'hotmail'],
#  ['arcangel.maite', 'gmail'],
#  ['argentinarumoaotri', 'yahoo'],
#  ['ariadinaalmeyda', 'gmail'],
#  ['ariadinaalmeyda', 'gmail'],
#  ['ariadinaalmeyda', 'gmail'],
#  ['ariadne_rebussi2', 'hotmail'],
#  ['ariana_dos_santos', 'yahoo'],
#  ['arianagalinari', 'hotmail'],
#  ['arianagalinari', 'hotmail'],
#  ['arianagrossi', 'yahoo'],
#  ['ariel_lou', 'hotmail'],
#  ['ariel05', 'uol'],
#  ['AriP.o', 'hotmail'],
#  ['AriP.o', 'hotmail'],
#  ['arthur.500', 'gmail'],
#  ['arthur25e', 'hotmail'],
#  ['arthurdenis', 'yahoo'],
#  ['arthurduda_santos', 'hotmail'],
#  ['arthurmalaguti', 'hotmail'],
#  ['arthurslipknot666', 'hotmail'],
#  ['arturpinheiropo', 'gmail'],
#  ['arturpinheiropo', 'gmail'],
#  ['arturvzf', 'yahoo'],
#  ['arydoido', 'gmail'],
#  ['asa_aguia', 'hotmail'],
#  ['asa_aguia', 'hotmail'],
#  ['ash_highschool', 'hotmail'],
#  ['ash_highschool', 'hotmail'],
#  ['ashley-uvinha', 'gmail'],
#  ['asmaisgatinhas05', 'yahoo'],
#  ['asmaisgatinhas05', 'yahoo'],
#  ['asmaisgatinhas06', 'yahoo'],
#  ['asmaisgatinhas06', 'yahoo'],
#  ['asmaisgatinhas07', 'yahoo'],
#  ['asmaisgatinhas07', 'yahoo'],
#  ['asmaisgatinhas08', 'yahoo'],
#  ['asmaisgatinhas08', 'yahoo'],
#  ['asmaisgatinhas10', 'yahoo'],
#  ['asmaisgatinhas10', 'yahoo'],
#  ['asmaisgatinhas10', 'yahoo'],
#  ['atds.du.funk', 'hotmail'],
#  ['athiagoc', 'hotmail'],
#  ['athiagoc', 'hotmail'],
#  ['athuscerezer', 'hotmail'],
#  ['atilagv171', 'hotmail'],
#  ['atilametal', 'gmail'],
#  ['atitud1000', 'hotmail'],
#  ['atlantisempire01', 'hotmail'],
#  ['atrevidoplay22', 'yahoo'],
#  ['atrevidoplay22', 'yahoo'],
#  ['atrevidoplay22', 'yahoo'],
#  ['atumdascondongas', 'yahoo'],
#  ['au', 'hot'],
#  ['audrey_eocara', 'hotmail'],
#  ['augusto.anjo', 'terra'],
#  ['auhuahuahuahuahuahuahuahauhauhau', 'yahoo'],
#  ['auhuahuahuahuahuahuahuahauhauhau', 'yahoo'],
#  ['aurezitablackwithe', 'hotmail'],
#  ['auto-compra', 'bol'],
#  ['av_taty', 'hotmail'],
#  ['avlannandes', 'hotmail'],
#  ['avril_fake_lokinha', 'hotmail'],
#  ['avrillavigneline', 'hotmail'],
#  ['axadosgovaladares', 'gmail'],
#  ['axadosmontesclaros', 'hotmail'],
#  ['ayanny_silva', 'hotmail'],
#  ['ayanny_silva', 'hotmail'],
#  ['ayesha_blanco15', 'hotmail'],
#  ['aylabalalaik', 'gmail'],
#  ['aylanyblg', 'hotmail'],
#  ['azurefrog', 'bol'],
#  ['b_boy_ita', 'hotmail'],
#  ['b_eyonc_e', 'yahoo'],
#  ['b_l_d_s', 'hotmail'],
#  ['b3.mariliavieira', 'hotmail'],
#  ['babi-barbra', 'hotmail'],
#  ['babu_nf', 'hotmail'],
#  ['baby_daianinha', 'hotmail'],
#  ['baby_daianinha', 'hotmail'],
#  ['babyblue_jeh', 'yahoo'],
#  ['babyblue_jeh', 'yahoo'],
#  ['babyblue_jeh', 'yahoo'],
#  ['babyblue_jeh', 'yahoo'],
#  ['backflip', 'cresce'],
#  ['backflip', 'cresce'],
#  ['badu_enos', 'hotmail'],
#  ['badu_enos', 'hotmail'],
#  ['bairrosdeguarulhos', 'gmail'],
#  ['baixinha_cinthia', 'hotmail'],
#  ['baixinha_cinthia', 'hotmail'],
#  ['baixinha_cinthia', 'hotmail'],
#  ['baixinhalindaalt', 'gmail'],
#  ['baixinhalindaalt', 'gmail'],
#  ['baixinhalindaalt', 'gmail'],
#  ['balada10.site', 'bol'],
#  ['Balanzinhooo', 'yahoo'],
#  ['balavoadora', 'hotmail'],
#  ['band_aid_tylenol_girl', 'hotmail'],
#  ['bandadescontrolegpi', 'hotmail'],
#  ['bang-loko', 'hotmail'],
#  ['bang-loko', 'hotmail'],
#  ['baratarebelde', 'gmail'],
#  ['barbara_jardim', 'hotmail'],
#  ['barbara_sri', 'yahoo'],
#  ['barbara_sri', 'yahoo'],
#  ['barbara_sri', 'yahoo'],
#  ['barbarababi23', 'yahoo'],
#  ['barbararynessa', 'yahoo'],
#  ['barbaravpanin', 'yahoo'],
#  ['barbiepunk182', 'hotmail'],
#  ['barby_fire', 'hotmail'],
#  ['barlungueiro', 'gmail'],
#  ['barroso_cow', 'yahoo'],
#  ['bart_simpsons_123', 'hotmail'],
#  ['bart_simpsons_123', 'hotmail'],
#  ['basili', 'pop'],
#  ['basketeira04', 'hotmail'],
#  ['batera_vitim', 'yahoo'],
#  ['batmanbegins321', 'yahoo'],
#  ['battagin.vendasmmn', 'yahoo'],
#  ['baxinirav', 'gmail'],
#  ['baxozinho', 'hotmail'],
#  ['baxozinho', 'hotmail'],
#  ['bbruno_marleyy', 'hotmail'],
#  ['bbruno_marleyy', 'hotmail'],
#  ['beatriz_pg', 'lindinha'],
#  ['beautiful-_-soul.ck', 'hotmail'],
#  ['bebado.renato', 'yahoo'],
#  ['bebado.renato', 'yahoo'],
#  ['bebado.renato', 'yahoo'],
#  ['bebelolsimplismente2', 'yahoo'],
#  ['bebelolsimplismente2', 'yahoo'],
#  ['bebelolsimplismente2', 'yahoo'],
#  ['bebelolsimplismente2', 'yahoo'],
#  ['bebetoluiz_bj', 'hotmail'],
#  ['bebezinhofn', 'yahoo'],
#  ['becaspears', 'yahoo'],
#  ['beckinhah_vip', 'yahoo'],
#  ['beiby_paixao', 'yahoo'],
#  ['bel_gatinhaloira', 'hotmail'],
#  ['bel_ipa', 'hotmail'],
#  ['bela.procura_fera', 'yahoo'],
#  ['belagatinha_9', 'hotmail'],
#  ['belezanegra1376', 'hotmail'],
#  ['belinha.uchoas', 'hotmail'],
#  ['belinhabaldow', 'hotmail'],
#  ['beloved22kinha', 'yahoo'],
#  ['belynhapoderosa', 'yahoo'],
#  ['beneirfelipe', 'gmail'],
#  ['benzmodtatoo2', 'gmail'],
#  ['benzmodtatoo2', 'gmail'],
#  ['betemcy_', 'hotmail'],
#  ['beth_taina', 'hotmail'],
#  ['bethymsn', 'hotmail'],
#  ['betina.s.costa', 'hotmail'],
#  ['betinhocomelli45', 'hotmail'],
#  ['beto2hader', 'hotmail'],
#  ['bettaniaramos', 'hotmail'],
#  ['Betynhah', 'hotmail'],
#  ['beyjomyu', 'hotmail'],
#  ['bflavia1', 'yahoo'],
#  ['bia.15', 'yahoo'],
#  ['bia__rg', 'hotmail'],
#  ['bia_amo_rosa', 'hotmail'],
#  ['bia_estrelinha', 'yahoo'],
#  ['bia_mimoza', 'hotmail'],
#  ['biageoava', 'yahoo'],
#  ['biagv16', 'hotmail'],
#  ['biagv16', 'hotmail'],
#  ['biagv16', 'hotmail'],
#  ['bialeao51', 'hotmail'],
#  ['biamilitao', 'hotmail'],
#  ['bianca_0093', 'yahoo'],
#  ['bianca_linda_14', 'hotmail'],
#  ['bianca_mv_23', 'hotmail'],
#  ['bianca_paulino', 'yahoo'],
#  ['biank_rubim', 'hotmail'],
#  ['biankinha_biazuda', 'hotmail'],
#  ['biankuxaaa4', 'yahoo'],
#  ['biashao', 'gmail'],
#  ['biazinha.trance', 'hotmail'],
#  ['biazinha2007new', 'gmail'],
#  ['biazinha2007new', 'gmail'],
#  ['biazinha2007new', 'gmail'],
#  ['bibian_mendes', 'yahoo'],
#  ['bibica-banho', 'bol'],
#  ['bidu.hlb', 'msn'],
#  ['bidu.hlb', 'msn'],
#  ['bieeeel__', 'hotmail'],
#  ['biel.kriok', 'yahoo'],
#  ['bielggato', 'hotmail'],
#  ['bien.feio', 'gmail'],
#  ['bien.feio', 'gmail'],
#  ['bien.feio', 'gmail'],
#  ['bien.feio', 'gmail'],
#  ['bienvenue.france', 'yahoo'],
#  ['bieo_vibe', 'hotmail'],
#  ['bigmouth0000', 'yahoo'],
#  ['biiiah.__', 'hotmail'],
#  ['biiiah_js', 'yahoo'],
#  ['bilban41', 'hotmail'],
#  ['bill-_', 'hotmail'],
#  ['bill_abr', 'hotmail'],
#  ['billabong17', 'jim'],
#  ['billabong18', 'jim'],
#  ['billabong2', 'jim'],
#  ['billabong20', 'jim'],
#  ['billabong3', 'jim'],
#  ['billabong4', 'jim'],
#  ['billabong8', 'jim'],
#  ['billy', 'oi'],
#  ['bin_rulez', 'hotmail'],
#  ['binhaloirinha', 'bol'],
#  ['binhanha001', 'hotmail'],
#  ['binhanha001', 'hotmail'],
#  ['binhanha001', 'hotmail'],
#  ['binho_fofinhu', 'hotmail'],
#  ['bioffcrash', 'msn'],
#  ['biscatao', 'gmail'],
#  ['bisquim_sk8', 'hotmail'],
#  ['bisteka_1', 'hotmail'],
#  ['bizinha13', 'bol'],
#  ['bj_df', 'hotmail'],
#  ['bjorkfull', 'gmail'],
#  ['bl4bl4bl4.01', 'gmail'],
#  ['blackclown', 'exploits'],
#  ['blackclown', 'exploits'],
#  ['blacktem10', 'hotmail'],
#  ['blacktem10', 'hotmail'],
#  ['blacktem10', 'hotmail'],
#  ['blacktsun', 'gmail'],
#  ['blacktsun', 'gmail'],
#  ['blacktsun', 'gmail'],
#  ['bladeknight.fake', 'yahoo'],
#  ['blaynner_sk8', 'hotmail'],
#  ['blaynner_sk8', 'hotmail'],
#  ['blondergrasi', 'hotmail'],
#  ['blordao', 'yahoo'],
#  ['blu.william', 'gmail'],
#  ['blue_dolphin_2005', 'hotmail'],
#  ['bobsponja6', 'gmail'],
#  ['bok_sexy', 'hotmail'],
#  ['bol.alt', 'bol'],
#  ['bol.alt', 'bol'],
#  ['bola_original', 'hotmail'],
#  ['bombom-cg', 'hotmail'],
#  ['boneca.sapekinha', 'hotmail'],
#  ['bonekinhav', 'hotmail'],
#  ['bonequinha1', 'boneca'],
#  ['boo_poletto', 'yahoo'],
#  ['borisjua', 'gmail'],
#  ['borisjua', 'gmail'],
#  ['borisjua', 'gmail'],
#  ['boto_stm', 'hotmail'],
#  ['bozo_lp_2', 'yahoo'],
#  ['br88jp', 'gmail'],
#  ['braeckevelt', 'pandora'],
#  ['braiannunes', 'yahoo'],
#  ['braiannunes', 'yahoo'],
#  ['brainstorming.br', 'gmail'],
#  ['brancogoval', 'hotmail'],
#  ['brandynho__2007', 'hotmail'],
#  ['Brasil.Naruto', 'gmail'],
#  ['brawnzinho', 'hotmail'],
#  ['brawnzinho', 'hotmail'],
#  ['brawnzinho', 'hotmail'],
#  ['brayanphillcard', 'hotmail'],
#  ['brenda.pink', 'hotmail'],
#  ['brenda.pink', 'hotmail'],
#  ['brenda_msn', 'hotmail'],
#  ['brendavalente7', 'yahoo'],
#  ['brendavalente7', 'yahoo'],
#  ['brenna_rebelde', 'yahoo'],
#  ['breno.94', 'hotmail'],
#  ['breno_ribeiro14', 'hotmail'],
#  ['brilhoso', 'bol'],
#  ['brina_bina', 'hotmail'],
#  ['briscow', 'bol'],
#  ['britneyslaveforu2', 'yahoo'],
#  ['Britty.15', 'hotmail'],
#  ['Britty.15', 'hotmail'],
#  ['Britty.15', 'hotmail'],
#  ['brn_anjobp', 'hotmail'],
#  ['bro', 'codex'],
#  ['brrunoesper', 'yahoo'],
#  ['bru_emtt', 'hotmail'],
#  ['Bru_Galega_Sbo', 'hotmail'],
#  ['bru_mulamba', 'hotmail'],
#  ['bruh.kittie', 'yahoo'],
#  ['bruh_verycat', 'yahoo'],
#  ['bruhpedrotti', 'yahoo'],
#  ['brum-allan2', 'bol'],
#  ['bruna.xnd', 'bol'],
#  ['bruna_290395', 'yahoo'],
#  ['bruna_amelhor15', 'hotmail'],
#  ['Bruna_barbara', 'yahoo'],
#  ['bruna_danisjc', 'yahoo'],
#  ['bruna_fenix', 'yahoo'],
#  ['bruna_mageste', 'hotmail'],
#  ['bruna_morato', 'yahoo'],
#  ['bruna_ricciardi', 'hotmail'],
#  ['bruna_ricciardi', 'hotmail'],
#  ['bruna_santos33', 'yahoo'],
#  ['Brunaa.CR7', 'hotmail'],
#  ['Brunaa.CR7', 'hotmail'],
#  ['brunacajano', 'hotmail'],
#  ['brunacarvalho9', 'bol'],
#  ['brunad2007', 'yahoo'],
#  ['brunagz', 'ig'],
#  ['brunaleepitty', 'yahoo'],
#  ['brunambn', 'hotmail'],
#  ['brunao_wesley', 'hotmail'],
#  ['brunapenti', 'gmail'],
#  ['brunela-92', 'hotmail'],
#  ['bruni_sm', 'yahoo'],
#  ['bruni_sm', 'yahoo'],
#  ['brunim.orkut', 'bol'],
#  ['brunim_dj', 'hotmail'],
#  ['bruninha.caroline', 'oi'],
#  ['bruninha.caroline', 'oi'],
#  ['bruninha_dorkut', 'yahoo'],
#  ['bruninha_hta00', 'hotmail'],
#  ['bruninha_hta00', 'hotmail'],
#  ['bruninha_hta00', 'hotmail'],
#  ['bruninha_kitti', 'yahoo'],
#  ['bruninha_loirinha13', 'yahoo'],
#  ['bruninhas2fofuxinha', 'yahoo'],
#  ['bruninho_da_praia', 'hotmail'],
#  ['bruninho_pettersen', 'hotmail'],
#  ['brunna.sk8', 'hotmail'],
#  ['brunna775', 'yahoo'],
#  ['brunnnynha', 'gmail'],
#  ['brunnodorosa', 'hotmail'],
#  ['brunnodorosa', 'hotmail'],
#  ['brunnodorosa', 'hotmail'],
#  ['bruno.mam', 'hotmail'],
#  ['bruno.sp.soad', 'bol'],
#  ['bruno.sp.soad', 'bol'],
#  ['bruno.uc', 'hotmail'],
#  ['Bruno__travassos', 'hotmail'],
#  ['bruno_colpes', 'hotmail'],
#  ['bruno_eminem2', 'hotmail'],
#  ['bruno_eminem2', 'hotmail'],
#  ['bruno_eminem2', 'hotmail'],
#  ['bruno_eminem2', 'hotmail'],
#  ['bruno_gatomalvado', 'hotmail'],
#  ['bruno_graciotto', 'hotmail'],
#  ['bruno_jvmk', 'yahoo'],
#  ['bruno_kazuhiro', 'hotmail'],
#  ['bruno_lfp', 'hotmail'],
#  ['bruno_mapcr', 'hotmail'],
#  ['bruno_moreno_19', 'hotmail'],
#  ['bruno_pegador', 'oi'],
#  ['bruno_portuga22', 'yahoo'],
#  ['bruno_salam', 'hotmail'],
#  ['bruno_santiago_3000', 'hotmail'],
#  ['Bruno_Santos_2004', 'hotmail'],
#  ['bruno_spider17', 'yahoo'],
#  ['bruno_vader', 'hotmail'],
#  ['bruno29_verde', 'yahoo'],
#  ['bruno29_verde', 'yahoo'],
#  ['bruno-amoral', 'hotmail'],
#  ['bruno-amoral', 'hotmail'],
#  ['bruno-d10', 'hotmail'],
#  ['brunodjmc', 'bol'],
#  ['brunofurious', 'oi'],
#  ['bruno-grapex', 'bol'],
#  ['brunohelenonascimento', 'yahoo'],
#  ['brunohelenonascimento', 'yahoo'],
#  ['brunohenriquef', 'ig'],
#  ['brunolimanascimento', 'yahoo'],
#  ['brunopasteleiro', 'hotmail'],
#  ['brunopopvip', 'yahoo'],
#  ['brunorgato', 'hotmail'],
#  ['brunorgato', 'hotmail'],
#  ['brunosoadrock', 'hotmail'],
#  ['brunosuper123', 'yahoo'],
#  ['brunotecnodjs', 'hotmail'],
#  ['brunovioleiro', 'yahoo'],
#  ['Brunynha_grings', 'pop'],
#  ['brunynha_mary', 'hotmail'],
#  ['brunynha_tgs', 'yahoo'],
#  ['brunynha_z16', 'yahoo'],
#  ['brunynho_surf', 'yahoo'],
#  ['bryan.eliziario', 'bol'],
#  ['bryan.eliziario', 'bol'],
#  ['bryan.eliziario', 'bol'],
#  ['bryanadams', 'fox'],
#  ['bryanadams', 'fox'],
#  ['bryanadams', 'fox'],
#  ['bryanadams', 'fox'],
#  ['btt-gualberto', 'hotmail'],
#  ['bu9506', 'hotmail'],
#  ['bucha_skateboard', 'hotmail'],
#  ['buda92', 'bol'],
#  ['bunequinha_gv', 'hotmail'],
#  ['bunno_cardozo', 'yahoo'],
#  ['bw.gonzales', 'bol'],
#  ['bwolker', 'zipmail'],
#  ['bya-carneiro', 'bol'],
#  ['bya-carneiro', 'bol'],
#  ['bzebele', 'hotmail'],
#  ['c_he_le_18', 'hotmail'],
#  ['c4fezinho', 'yahoo'],
#  ['ca_io_16', 'yahoo'],
#  ['caanelinha_', 'hotmail'],
#  ['cabritaguerreira', 'hotmail'],
#  ['cabritaguerreira', 'hotmail'],
#  ['cabritaguerreira', 'hotmail'],
#  ['cacalocomotive', 'hotmail'],
#  ['caca-s2', 'hotmail'],
#  ['cacmayara', 'yahoo'],
#  ['cah_pinkk', 'yahoo'],
#  ['cah_soad', 'hotmail'],
#  ['cahprincess', 'hotmail'],
#  ['caio.plaboy', 'gmail'],
#  ['caio.plaboy', 'gmail'],
#  ['caio.plaboy', 'gmail'],
#  ['caio.plaboy', 'gmail'],
#  ['caio_rodrigues04', 'yahoo'],
#  ['caio167', 'hotmail'],
#  ['caioaugustocrippa', 'bol'],
#  ['caioaugustocrippa', 'bol'],
#  ['caiobode', 'yahoo'],
#  ['caiobode', 'yahoo'],
#  ['caiobode', 'yahoo'],
#  ['caioempadinha', 'hotmail'],
#  ['caiohaas', 'yahoo'],
#  ['CAIOSAL', 'CLICK21'],
#  ['caiquebaggio', 'bol'],
#  ['caiquebaggio', 'bol'],
#  ['caiquebaggio', 'bol'],
#  ['cajrepre1', 'hotmail'],
#  ['calbuquerquegv', 'hotmail'],
#  ['calistoni', 'gmail'],
#  ['cambraiadhc', 'yahoo'],
#  ['camila.argentao', 'bol'],
#  ['camila.md.16', 'hotmail'],
#  ['camila.mello', 'hotmail'],
#  ['camila.mv', 'hotmail'],
#  ['camila.ochoa', 'terra'],
#  ['camila.ochoa', 'terra'],
#  ['camila.trust', 'hotmail'],
#  ['camila_cat', 'yahoo'],
#  ['camila_cayres', 'hotmail'],
#  ['camila_cayres', 'hotmail'],
#  ['camila_cayres', 'hotmail'],
#  ['camila_cayres', 'hotmail'],
#  ['camila_matos63', 'hotmail'],
#  ['camila_morena12', 'hotmail'],
#  ['camila_sk8_2005', 'yahoo'],
#  ['camilafernandes15', 'bol'],
#  ['camilafernandes15', 'bol'],
#  ['camilafernandes15', 'bol'],
#  ['camilalealmsn', 'gmail'],
#  ['camilametzker', 'yahoo'],
#  ['camilar-alt', 'yahoo'],
#  ['camilar-alt', 'yahoo'],
#  ['camilar-alt', 'yahoo'],
#  ['camilatavare', 'gmail'],
#  ['camilinha.bibi', 'hotmail'],
#  ['cammilla4', 'hotmail'],
#  ['camposfisiocopeico', 'yahoo'],
#  ['camposgontijo', 'yahoo'],
#  ['camysouza', 'hotmail'],
#  ['cao.cao', 'hotmail'],
#  ['caocorage', 'gmail'],
#  ['cap.jack01', 'gmail'],
#  ['capiitao', 'hotmail'],
#  ['capoerista_ilha', 'hotmail'],
#  ['caprice_beautifull', 'yahoo'],
#  ['CARCEREIROSMS', 'HOTMAIL'],
#  ['careca_01', 'ig'],
#  ['carine.gabriella', 'gmail'],
#  ['carioca93', 'uol'],
#  ['carla.graczcki', 'gmail'],
#  ['carla_leticiaos', 'hotmail'],
#  ['carla_leticiaos', 'hotmail'],
#  ['carla_oneida', 'hotmail'],
#  ['carla_rock1000', 'hotmail'],
#  ['carladedeus', 'gmail'],
#  ['carladedeus', 'gmail'],
#  ['carladedeus', 'gmail'],
#  ['carladedeus', 'gmail'],
#  ['carlafabricia1', 'hotmail'],
#  ['carlakeissiane', 'bol'],
#  ['carlalovato1', 'hotmail'],
#  ['carlamoniquerio', 'hotmail'],
#  ['carlanahiara_15', 'hotmail'],
#  ['carlatonton', 'yahoo'],
#  ['carlavipgv', 'hotmail'],
#  ['carlinha405', 'hotmail'],
#  ['carlinha-apaixonada', 'hotmail'],
#  ['carlinha-apaixonada', 'hotmail'],
#  ['carlinha-apaixonada', 'hotmail'],
#  ['carlinhosbaixinho1', 'yahoo'],
#  ['carlinhosbaixinho1', 'yahoo'],
#  ['carlitoscp_cf', 'hotmail'],
#  ['carllisgeisonglesilion123', 'bol'],
#  ['carlos_souza14', 'hotmail'],
#  ['carlos_souza14', 'hotmail'],
#  ['carlosalberto_157', 'col'],
#  ['Carlosepjr666', 'hotmail'],
#  ['carlosival', 'walla'],
#  ['carlosjunior891', 'hotmail'],
#  ['carlosjunior891', 'hotmail'],
#  ['carlosmg2005', 'msn'],
#  ['carlosranma', 'hotmail'],
#  ['carlosrodrigues24', 'yahoo'],
#  ['carlosrodrigues24', 'yahoo'],
#  ['carlozlukax', 'hotmail'],
#  ['carol.beender', 'gmail'],
#  ['carol_2005pink', 'hotmail'],
#  ['carol_car_42', 'hotmail'],
#  ['carol_gomes.silva', 'hotmail'],
#  ['carol_gomes.silva', 'hotmail'],
#  ['carol_gommes2000', 'hotmail'],
#  ['carol_natiruts', 'yahoo'],
#  ['carol_pp_15', 'yahoo'],
#  ['carol_starmodel', 'yahoo'],
#  ['carol_volei555', 'yahoo'],
#  ['carol-116', 'hotmail'],
#  ['carolaine_rj2006', 'yahoo'],
#  ['carolfs_jf', 'yahoo'],
#  ['carolinamancine', 'yahoo'],
#  ['carolinanevesgv', 'bol'],
#  ['carolinasp.rbd', 'gmail'],
#  ['carolinatalpo', 'hotmail'],
#  ['caroline_bdl', 'hotmail'],
#  ['caroline_thuthuca', 'yahoo'],
#  ['carolineaparecida', 'oi'],
#  ['carolineaparecida', 'oi'],
#  ['carolineaparecida', 'oi'],
#  ['carolineestefanizanin', 'yahoo'],
#  ['carolineestefanizanin', 'yahoo'],
#  ['carolineestefanizanin', 'yahoo'],
#  ['carolineestefanizanin', 'yahoo'],
#  ['carolinefav', 'bol'],
#  ['caroline-goncalves1994', 'bol'],
#  ['carolinegv_17', 'yahoo'],
#  ['carolinehh_', 'hotmail'],
#  ['carolineromao_htinha', 'hotmail'],
#  ['carolineromao_htinha', 'hotmail'],
#  ['carolpvh_andrade', 'hotmail'],
#  ['carolrscheke', 'hotmail'],
#  ['carolzinha_meninalinda', 'yahoo'],
#  ['carolzinha_meninalinda', 'yahoo'],
#  ['carolzinhamuller', 'bol'],
#  ['carolzitanobrega', 'hotmail'],
#  ['carom_gg', 'yahoo'],
#  ['carom_gg', 'yahoo'],
#  ['carom_gg', 'yahoo'],
#  ['carreg13', 'gmail'],
#  ['carreg13', 'gmail'],
#  ['carreiro288', 'hotmail'],
#  ...]

# %% [markdown]
# ## E4.3
# Dada a lista de emails do exercício anterior, crie uma tabela com o seguinte formato:
#
# ```
# Login               Dominio
# login1              dominio1
# login2              domonio2
# loginn              dominion
# ```

# %%
def pretty_print(login_dominio):
    login, dominio = login_dominio
    nLogin = 60 - len(login)
    print(login + nLogin * ' ' + dominio)

# %%
pretty_print(['LOGIN', 'DOMINIO'])

for i in resposta:
    pretty_print(i)
# Out:
# LOGIN                                                       DOMINIO
# a3sign                                                      pandora
# aaanika2                                                    hotmail
# aaron2003s                                                  bol
# aaron--21                                                   hotmail
# abidoral                                                    hotmail
# abk_333                                                     hotmail
# abner_bim                                                   hotmail
# abner_bim                                                   hotmail
# acacio_divix                                                hotmail
# academia.boaforma                                           yahoo
# ac-ferian                                                   bol
# acordarsono                                                 hotmail
# acsa_lim                                                    yahoo
# adamyth                                                     gmail
# add_ae_jente                                                yahoo
# addgeral                                                    gmail
# addyevusk                                                   yahoo
# adeozemir                                                   yahoo
# adhaha                                                      gmail
# adhaha                                                      gmail
# adidas__star                                                hotmail
# adidas__star                                                hotmail
# adilio-vidaloka                                             yahoo
# adilson.mariano5                                            terra
# admgerald1                                                  yahoo
# adri_barboza                                                hotmail
# adri_barboza                                                hotmail
# adriaens                                                    pandora
# adrian_boyzinhu                                             yahoo
# adriana_lemes_farias                                        hotmail
# adriana_lemes_farias                                        hotmail
# adrianacpx                                                  yahoo
# adriane_do_prado                                            yahoo
# adrianinhaim                                                bol
# adrianinhaim                                                bol
# adrianinhaxp                                                yahoo
# adriano.fariasnascimento                                    yahoo
# adriano_wolf1                                               hotmail
# adrianogato.2007                                            hotmail
# adrianojareck                                               hotmail
# adrianonev3s                                                gmail
# adrianosenna                                                yahoo
# adrianraniery                                               bol
# Adriedson88                                                 hotmail
# adrieli_baldoria                                            hotmail
# adrielle_amaral                                             yahoo
# adrielli_cr                                                 hotmail
# adrielly                                                    yaroo
# adrielly_silva                                              yaroo
# adriely_94                                                  hotmail
# adrienevinhote                                              hotmail
# adryana_maia                                                hotmail
# adryana_maia                                                hotmail
# adryana_maia                                                hotmail
# adryshevchenko7                                             hotmail
# adryshevchenko7                                             yahoo
# adryshevchenko7                                             hotmail
# a-ferraz                                                    bol
# afonso-catador                                              hotmail
# afonso-catador                                              hotmail
# afonsoducarmo                                               yahoo
# afrancar15                                                  yahoo
# agatha_rosa8                                                yahoo
# agatha_rosa8                                                yahoo
# agente_fbi13                                                yahoo
# agente_fbi13                                                yahoo
# agente_fbi13                                                yahoo
# agloco.com.fake                                             gmail
# agloco-sv                                                   bol
# agnaldojt                                                   hotmail
# agoraeuvodetona2                                            yahoo
# agoraeuvodetona2                                            yahoo
# agricesar                                                   yahoo
# agricesar                                                   yahoo
# agricesar                                                   yahoo
# aguia_fenix                                                 hotmail
# aguinaldo4789                                               hotmail
# aguinaldo4789                                               hotmail
# aguinaldo4789                                               hotmail
# ai_                                                         hotmail
# Aiacos.Kyoto                                                gmail
# aim.vip2                                                    hotmail
# aim.vip25                                                   hotmail
# aiopam                                                      hotmail
# aislyn14                                                    yahoo
# aislyn14                                                    yahoo
# ajudasystemonline                                           gmail
# ajuding.01                                                  hotmail
# akitanajura                                                 yahoo
# akitanajura                                                 yahoo
# ala-frei                                                    hotmail
# alahfilho                                                   gmail
# alan_gatinho_sjc                                            yahoo
# alan_kiedis2                                                yahoo
# alan_morenogato                                             hotmail
# alan_schmeiske                                              hotmail
# alandenissouza                                              hotmail
# alanfarias_18                                               yahoo
# alaninha_13                                                 hotmail
# alanjonny_rp89                                              hotmail
# alanjonny_rp89                                              hotmail
# alanmoreira12                                               yahoo
# Alanvitim                                                   yahoo
# alanyseyes                                                  msn
# alanzin.mel                                                 hotmail
# alareskamartins                                             hotmail
# albinorios2                                                 hotmail
# albinorios2                                                 hotmail
# aldy.serg                                                   uol
# ale_amor05                                                  hotmail
# ale_amor05                                                  hotmail
# ale_amor05                                                  hotmail
# ale_amor05                                                  hotmail
# ale_zinha_hta                                               hotmail
# aleckis_97                                                  hotmail
# aleckis_97                                                  hotmail
# aleckis_97                                                  hotmail
# aledickinsooon                                              hotmail
# alef_saopaulo                                               yahoo
# alemao_alison                                               hotmail
# Aleson_pml                                                  yahoo
# aless_pina25                                                hotmail
# alessandrabrittosouza                                       gmail
# alessandralazarini                                          yahoo
# alessandranyzewski                                          yahoo
# alessandrofortuna1                                          hotmail
# alex.3carlos                                                yahoo
# alex_betalia                                                hotmail
# alex_betalia                                                hotmail
# alex_farkas                                                 hotmail
# alex_llk                                                    yahoo
# ALEX91BADBOY                                                YAHOO
# ALEX91BADBOY                                                YAHOO
# ALEX91BADBOY                                                YAHOO
# alexandra_assaf                                             hotmail
# alexandra_praca                                             hotmail
# alexandre.audi                                              uol
# alexandre.carreiro                                          gmail
# alexandre.goes                                              hotmail
# alexandre.stoian2                                           gmail
# alexandreairtonreisteles                                    yahoo
# alexandrecachapus                                           yahoo
# alexandressmelo                                             hotmail
# alexandretormen                                             hotmail
# alexandretormen                                             hotmail
# alexandrinho_tdb64                                          yahoo
# alexandrino.thiago                                          gmail
# alexbegins                                                  hotmail
# alexcabeludo2                                               hotmail
# alexcabeludo2                                               hotmail
# alexd3                                                      gmail
# alexfonsek                                                  yahoo
# alexmendesskt                                               yahoo
# alexrdgs.89                                                 gmail
# alexrosa55                                                  yahoo
# alexsandro004                                               uol
# alexsandrotavares                                           msn
# alextsm10                                                   yahoo
# alexwaldo                                                   globo
# alfonsogatto10000                                           hotmail
# alfredochallco                                              bol
# algmjaescolheuessenomedeusuario                             yahoo
# ALI.SILVA                                                   HOTMAIL
# alice_xmedeiros                                             yahoo
# aline.moretti.sanches                                       gmail
# aline.moretti.sanches                                       gmail
# aline.rickmann                                              ig
# aline__patty                                                hotmail
# aline_aquino                                                oi
# aline_boladona2006                                          hotmail
# aline_gatinha_13                                            yahoo
# aline_rbd_rx                                                hotmail
# aline_reggae13                                              hotmail
# aline_reggae13                                              hotmail
# aline_sakuray                                               hotmail
# aline_somg                                                  hotmail
# aline-150793                                                hotmail
# alinealg                                                    yahoo
# alinebmb                                                    gmail
# alinecordeiro_17                                            hotmail
# alinecordeiro_17                                            hotmail
# alinedaniele_14                                             yahoo
# alinedantas4                                                gmail
# alineferreira_01                                            yahoo
# alinegcanta                                                 hotmail
# alinegirl_49                                                hotmail
# alineilima                                                  hotmail
# alinejaque                                                  gmail
# alinejaque                                                  gmail
# alinenewjersey                                              msn
# alinenj_usa                                                 yahoo
# alineoliveiraes                                             gmail
# alineteacher                                                yahoo
# alineteacher                                                yahoo
# alinewolff                                                  hotmail
# alininhaderaul                                              yahoo
# alininhaderaul                                              yahoo
# alinyfereira                                                yahoo
# alisson.marquessss                                          gmail
# alisson.marquessss                                          gmail
# allan.teodoro                                               gmail
# allan_17_1309                                               hotmail
# allan_17_1309                                               hotmail
# allanbraga11                                                hotmail
# allancalipio                                                bol
# allannynhah_15                                              hotmail
# allansilvasouza                                             hotmail
# allansisti                                                  hotmail
# allex_pe                                                    hotmail
# allysson.camillo                                            Gmail
# allyssoncachorroloko                                        hotmail
# alonsomaria                                                 bol
# alonsomaria                                                 bol
# altamirfilho                                                gmail
# altamirfilho                                                gmail
# altamirfilho                                                gmail
# aluapinh                                                    yahoo
# alvaro_borges                                               hotmail
# alvarovallecamargos                                         yahoo
# alyne_ns                                                    hotmail
# amanda.kell                                                 yahoo
# amanda-_lima                                                hotmail
# amanda_rribeiro                                             hotmail
# amanda_rribeiro                                             hotmail
# amanda_rribeiro                                             hotmail
# amandadosreiscardozo                                        hotmail
# amandakell                                                  uol
# amandalenzpszybilski14                                      yahoo
# amandamedeiros22                                            hotmail
# amandanayara_nana                                           hotmail
# amandapriscila_bq                                           yahoo
# amandaroveri                                                hotmail
# amandaroveri                                                hotmail
# amandasantos_cruz                                           hotmail
# amandashirmay                                               hotmail
# amandasmith748                                              hotmail
# amandha1993                                                 hotmail
# amandinha_pink12                                            hotmail
# amandinha160                                                hotmail
# amandinhah_princess                                         msn
# amandinhalinda96                                            hotmail
# amandinhaop                                                 gmail
# amardita                                                    gmail
# amarlivrementeamar                                          hotmail
# amauri_file                                                 hotmail
# amaury_css                                                  hotmail
# amavel_ds                                                   yahoo
# amdkell                                                     gmail
# ameliacunha2                                                yahoo
# ameliacunha2                                                yahoo
# ameliacunha2                                                yahoo
# ammoal                                                      bol
# amo_amandakell                                              hotmail
# amorebeldedemais                                            bol
# ana.lacerda                                                 bol
# ana.lacerda                                                 bol
# ana.laura.zimmermann                                        hotmail
# ana.paula.vargas                                            hotmail
# ana.poc                                                     hotmail
# ana_12karla                                                 hotmail
# ana_ana_15                                                  live
# ana_carolmonteiro                                           hotmail
# ana_doidoina                                                hotmail
# ana_isabel153                                               hotmail
# ana_jac_16                                                  hotmail
# ana_paula_santos                                            msn
# ana_pr_amaral                                               hotmail
# ana_stek                                                    hotmail
# anacarolinapek                                              hotmail
# anacarolinapek                                              hotmail
# anaclaudia_faria01                                          yahoo
# anadpra                                                     yahoo
# anadpra                                                     yahoo
# Anaflavinhab                                                yahoo
# Anaflavinhab                                                yahoo
# anagatinha_msn                                              hotmail
# anahxc                                                      hotmail
# analimabittencourt                                          gmail
# analuizanascimento                                          bol
# analyne_divercao                                            yahoo
# ananda.sampaio                                              hotmail
# anandinhay_                                                 hotmail
# anandinhay_                                                 hotmail
# anao_psl                                                    hotmail
# anap_gatinha_2007                                           yahoo
# anapaula-orkut                                              hotmail
# anapaulapereira_15                                          yahoo
# anapaulapereira_15                                          yahoo
# anapaulapereira_15                                          yahoo
# anapaullaqueiroz                                            hotmail
# anapaullaqueiroz                                            hotmail
# anapaullaqueiroz                                            hotmail
# anaptbombig                                                 bol
# anas2s2dasilva                                              bol
# anascholl64                                                 hotmail
# anaselenem                                                  yahoo
# anaselenem                                                  yahoo
# anaselenem                                                  yahoo
# anasilva_alice                                              hotmail
# and.justice.for.all                                         bol
# ande_cobo                                                   hotmail
# ander_peu                                                   hotmail
# andersomzinhu                                               bol
# anderson.afsd                                               gmail
# anderson.afsd                                               gmail
# anderson.afsd                                               gmail
# anderson.psirico                                            yahoo
# anderson.s30                                                gmail
# anderson_fersilva                                           yahoo
# anderson_ups                                                yahoo
# andersonaraujob                                             gmail
# andersonbeliene3                                            gmail
# andersondoopala                                             hotmail
# andersongara                                                yahoo
# anderson-plasma                                             bol
# andersonsapolandia                                          gmail
# andersonsc182                                               yahoo
# anderson-sephiroth                                          hotmail
# andhesa                                                     bol
# andinhoufrn                                                 hotmail
# andradenego                                                 yahoo
# andre.floripas2                                             yahoo
# andre.rodolfo                                               ig
# andre.vincius                                               gmail
# andre.vincius                                               gmail
# andre.vincius                                               gmail
# andre.vincius                                               gmail
# andre_massot                                                ig
# andre_pitbulldoidera                                        yahoo
# andre_pitbulldoidera                                        yahoo
# andre_pitbulldoidera                                        yahoo
# andre_ritt                                                  hotmail
# andrea_araujo_br                                            yahoo
# andrea_fatima2005                                           hotmail
# andrea_fatima2005                                           hotmail
# andreasalles_12                                             hotmail
# andreasinnott                                               bol
# andrebarbosa28                                              yahoo
# andrebits                                                   bol
# andrebrownbiologia                                          oi
# andrecampos87                                               bol
# andrechsian                                                 bol
# andrechumbim                                                yahoo
# andrechumbim                                                yahoo
# andrechumbim                                                yahoo
# andredemais                                                 gmail
# andreiaregina_po                                            hotmail
# andreiaregina_po                                            hotmail
# andreiaregina_po                                            hotmail
# andreinha2007                                               hotmail
# andrel.xavier                                               yahoo
# andreluis_4499                                              hotmail
# andreluizgodoi                                              hotmail
# andremarques_vieira                                         yahoo
# andremeleite                                                gmail
# andrentfsowner                                              gmail
# andrentfsowner                                              gmail
# andresaopaulo2005                                           yahoo
# andressa.silva1994                                          bol
# andressa_galeazzi                                           hotmail
# andressa_hhh                                                hotmail
# andressafigura                                              yahoo
# andressasrhta                                               hotmail
# andretolentino262                                           hotmail
# andretolentino262                                           hotmail
# andretolentino262                                           hotmail
# andrevieiramonteiro                                         ibest
# andreza_badgirl                                             zipmail
# Andreza_mdm_                                                hotmail
# andrezapollo                                                bol
# andrezinhu.cs                                               bol
# aneliza_gatinha_12                                          hotmail
# anewragtiwari                                               gmail
# angeel_4                                                    hotmail
# angel_vick_fake                                             yahoo
# angela_jah                                                  hotmail
# angela_jah                                                  hotmail
# angela_jah                                                  hotmail
# angela_raimann                                              yahoo
# angelica.lucidia                                            gmail
# angelicaaltoe2                                              gmail
# angelical-cat17                                             hotmail
# angelicawonderful                                           yahoo
# angellouquinha                                              bol
# angelo647                                                   hotmail
# Angelofmelo                                                 portalcorinthians
# Angelofmelo                                                 portalcorinthians
# Angelofmelo                                                 portalcorinthians
# angel-perfect18                                             bol
# anielrte                                                    hotmail
# anielsath                                                   gmail
# anielsath                                                   gmail
# anielsath                                                   gmail
# anielsath2                                                  gmail
# anielsath2                                                  gmail
# anika_                                                      uol
# aninha_aas                                                  yahoo
# aninha_aas                                                  yahoo
# aninha_benfica                                              hotmail
# aninha_breezy3vax                                           yahoo
# aninha183                                                   hotmail
# aninhaa.cmo                                                 gmail
# aninhacordeiro                                              yahoo
# aninhagataloira                                             gmail
# aninha-gd-punk                                              bol
# aninhap.11                                                  hotmail
# aninhapaulinha88                                            yahoo
# aniram_life                                                 hotmail
# aniram_life                                                 hotmail
# aniram_life                                                 hotmail
# anjodomal_cs                                                hotmail
# anjogabrielresolve                                          yahoo
# anjometal5                                                  gmail
# anjonegroo                                                  yahoo
# anjonick                                                    hotmail
# anjorafaell21                                               yahoo
# anjosssssssss                                               yahoo
# Anna_criistina                                              hotmail
# annakeile                                                   yahoo
# annemievandevloed                                           pandora
# anninhakalil                                                hotmail
# annyhtona_                                                  hotmail
# annyjapa                                                    gmail
# annynhacarol123                                             hotmail
# annynhacarol123                                             hotmail
# annynhacarol123                                             hotmail
# annynicegirl                                                hotmail
# anonimo_add9                                                yahoo
# anonimo_bbb7                                                hotmail
# anonimo_nonu                                                yahoo
# antonia_gauchinha                                           yahoo
# antonio-tato18                                              bol
# antwantheswan                                               bol
# anynha_k3                                                   hotmail
# anynha_marin                                                hotmail
# anyyzuda                                                    hotmail
# anyzeenha                                                   yahoo
# apbj_hata                                                   hotmail
# apenaspruorkutdofer                                         hotmail
# apgfanap                                                    hotmail
# apgfanap                                                    hotmail
# apolo_deusdosol                                             hotmail
# aprivada2025                                                yahoo
# apsspoderosa                                                hotmail
# apsspoderosa                                                hotmail
# arcangel.maite                                              gmail
# argentinarumoaotri                                          yahoo
# ariadinaalmeyda                                             gmail
# ariadinaalmeyda                                             gmail
# ariadinaalmeyda                                             gmail
# ariadne_rebussi2                                            hotmail
# ariana_dos_santos                                           yahoo
# arianagalinari                                              hotmail
# arianagalinari                                              hotmail
# arianagrossi                                                yahoo
# ariel_lou                                                   hotmail
# ariel05                                                     uol
# AriP.o                                                      hotmail
# AriP.o                                                      hotmail
# arthur.500                                                  gmail
# arthur25e                                                   hotmail
# arthurdenis                                                 yahoo
# arthurduda_santos                                           hotmail
# arthurmalaguti                                              hotmail
# arthurslipknot666                                           hotmail
# arturpinheiropo                                             gmail
# arturpinheiropo                                             gmail
# arturvzf                                                    yahoo
# arydoido                                                    gmail
# asa_aguia                                                   hotmail
# asa_aguia                                                   hotmail
# ash_highschool                                              hotmail
# ash_highschool                                              hotmail
# ashley-uvinha                                               gmail
# asmaisgatinhas05                                            yahoo
# asmaisgatinhas05                                            yahoo
# asmaisgatinhas06                                            yahoo
# asmaisgatinhas06                                            yahoo
# asmaisgatinhas07                                            yahoo
# asmaisgatinhas07                                            yahoo
# asmaisgatinhas08                                            yahoo
# asmaisgatinhas08                                            yahoo
# asmaisgatinhas10                                            yahoo
# asmaisgatinhas10                                            yahoo
# asmaisgatinhas10                                            yahoo
# atds.du.funk                                                hotmail
# athiagoc                                                    hotmail
# athiagoc                                                    hotmail
# athuscerezer                                                hotmail
# atilagv171                                                  hotmail
# atilametal                                                  gmail
# atitud1000                                                  hotmail
# atlantisempire01                                            hotmail
# atrevidoplay22                                              yahoo
# atrevidoplay22                                              yahoo
# atrevidoplay22                                              yahoo
# atumdascondongas                                            yahoo
# au                                                          hot
# audrey_eocara                                               hotmail
# augusto.anjo                                                terra
# auhuahuahuahuahuahuahuahauhauhau                            yahoo
# auhuahuahuahuahuahuahuahauhauhau                            yahoo
# aurezitablackwithe                                          hotmail
# auto-compra                                                 bol
# av_taty                                                     hotmail
# avlannandes                                                 hotmail
# avril_fake_lokinha                                          hotmail
# avrillavigneline                                            hotmail
# axadosgovaladares                                           gmail
# axadosmontesclaros                                          hotmail
# ayanny_silva                                                hotmail
# ayanny_silva                                                hotmail
# ayesha_blanco15                                             hotmail
# aylabalalaik                                                gmail
# aylanyblg                                                   hotmail
# azurefrog                                                   bol
# b_boy_ita                                                   hotmail
# b_eyonc_e                                                   yahoo
# b_l_d_s                                                     hotmail
# b3.mariliavieira                                            hotmail
# babi-barbra                                                 hotmail
# babu_nf                                                     hotmail
# baby_daianinha                                              hotmail
# baby_daianinha                                              hotmail
# babyblue_jeh                                                yahoo
# babyblue_jeh                                                yahoo
# babyblue_jeh                                                yahoo
# babyblue_jeh                                                yahoo
# backflip                                                    cresce
# backflip                                                    cresce
# badu_enos                                                   hotmail
# badu_enos                                                   hotmail
# bairrosdeguarulhos                                          gmail
# baixinha_cinthia                                            hotmail
# baixinha_cinthia                                            hotmail
# baixinha_cinthia                                            hotmail
# baixinhalindaalt                                            gmail
# baixinhalindaalt                                            gmail
# baixinhalindaalt                                            gmail
# balada10.site                                               bol
# Balanzinhooo                                                yahoo
# balavoadora                                                 hotmail
# band_aid_tylenol_girl                                       hotmail
# bandadescontrolegpi                                         hotmail
# bang-loko                                                   hotmail
# bang-loko                                                   hotmail
# baratarebelde                                               gmail
# barbara_jardim                                              hotmail
# barbara_sri                                                 yahoo
# barbara_sri                                                 yahoo
# barbara_sri                                                 yahoo
# barbarababi23                                               yahoo
# barbararynessa                                              yahoo
# barbaravpanin                                               yahoo
# barbiepunk182                                               hotmail
# barby_fire                                                  hotmail
# barlungueiro                                                gmail
# barroso_cow                                                 yahoo
# bart_simpsons_123                                           hotmail
# bart_simpsons_123                                           hotmail
# basili                                                      pop
# basketeira04                                                hotmail
# batera_vitim                                                yahoo
# batmanbegins321                                             yahoo
# battagin.vendasmmn                                          yahoo
# baxinirav                                                   gmail
# baxozinho                                                   hotmail
# baxozinho                                                   hotmail
# bbruno_marleyy                                              hotmail
# bbruno_marleyy                                              hotmail
# beatriz_pg                                                  lindinha
# beautiful-_-soul.ck                                         hotmail
# bebado.renato                                               yahoo
# bebado.renato                                               yahoo
# bebado.renato                                               yahoo
# bebelolsimplismente2                                        yahoo
# bebelolsimplismente2                                        yahoo
# bebelolsimplismente2                                        yahoo
# bebelolsimplismente2                                        yahoo
# bebetoluiz_bj                                               hotmail
# bebezinhofn                                                 yahoo
# becaspears                                                  yahoo
# beckinhah_vip                                               yahoo
# beiby_paixao                                                yahoo
# bel_gatinhaloira                                            hotmail
# bel_ipa                                                     hotmail
# bela.procura_fera                                           yahoo
# belagatinha_9                                               hotmail
# belezanegra1376                                             hotmail
# belinha.uchoas                                              hotmail
# belinhabaldow                                               hotmail
# beloved22kinha                                              yahoo
# belynhapoderosa                                             yahoo
# beneirfelipe                                                gmail
# benzmodtatoo2                                               gmail
# benzmodtatoo2                                               gmail
# betemcy_                                                    hotmail
# beth_taina                                                  hotmail
# bethymsn                                                    hotmail
# betina.s.costa                                              hotmail
# betinhocomelli45                                            hotmail
# beto2hader                                                  hotmail
# bettaniaramos                                               hotmail
# Betynhah                                                    hotmail
# beyjomyu                                                    hotmail
# bflavia1                                                    yahoo
# bia.15                                                      yahoo
# bia__rg                                                     hotmail
# bia_amo_rosa                                                hotmail
# bia_estrelinha                                              yahoo
# bia_mimoza                                                  hotmail
# biageoava                                                   yahoo
# biagv16                                                     hotmail
# biagv16                                                     hotmail
# biagv16                                                     hotmail
# bialeao51                                                   hotmail
# biamilitao                                                  hotmail
# bianca_0093                                                 yahoo
# bianca_linda_14                                             hotmail
# bianca_mv_23                                                hotmail
# bianca_paulino                                              yahoo
# biank_rubim                                                 hotmail
# biankinha_biazuda                                           hotmail
# biankuxaaa4                                                 yahoo
# biashao                                                     gmail
# biazinha.trance                                             hotmail
# biazinha2007new                                             gmail
# biazinha2007new                                             gmail
# biazinha2007new                                             gmail
# bibian_mendes                                               yahoo
# bibica-banho                                                bol
# bidu.hlb                                                    msn
# bidu.hlb                                                    msn
# bieeeel__                                                   hotmail
# biel.kriok                                                  yahoo
# bielggato                                                   hotmail
# bien.feio                                                   gmail
# bien.feio                                                   gmail
# bien.feio                                                   gmail
# bien.feio                                                   gmail
# bienvenue.france                                            yahoo
# bieo_vibe                                                   hotmail
# bigmouth0000                                                yahoo
# biiiah.__                                                   hotmail
# biiiah_js                                                   yahoo
# bilban41                                                    hotmail
# bill-_                                                      hotmail
# bill_abr                                                    hotmail
# billabong17                                                 jim
# billabong18                                                 jim
# billabong2                                                  jim
# billabong20                                                 jim
# billabong3                                                  jim
# billabong4                                                  jim
# billabong8                                                  jim
# billy                                                       oi
# bin_rulez                                                   hotmail
# binhaloirinha                                               bol
# binhanha001                                                 hotmail
# binhanha001                                                 hotmail
# binhanha001                                                 hotmail
# binho_fofinhu                                               hotmail
# bioffcrash                                                  msn
# biscatao                                                    gmail
# bisquim_sk8                                                 hotmail
# bisteka_1                                                   hotmail
# bizinha13                                                   bol
# bj_df                                                       hotmail
# bjorkfull                                                   gmail
# bl4bl4bl4.01                                                gmail
# blackclown                                                  exploits
# blackclown                                                  exploits
# blacktem10                                                  hotmail
# blacktem10                                                  hotmail
# blacktem10                                                  hotmail
# blacktsun                                                   gmail
# blacktsun                                                   gmail
# blacktsun                                                   gmail
# bladeknight.fake                                            yahoo
# blaynner_sk8                                                hotmail
# blaynner_sk8                                                hotmail
# blondergrasi                                                hotmail
# blordao                                                     yahoo
# blu.william                                                 gmail
# blue_dolphin_2005                                           hotmail
# bobsponja6                                                  gmail
# bok_sexy                                                    hotmail
# bol.alt                                                     bol
# bol.alt                                                     bol
# bola_original                                               hotmail
# bombom-cg                                                   hotmail
# boneca.sapekinha                                            hotmail
# bonekinhav                                                  hotmail
# bonequinha1                                                 boneca
# boo_poletto                                                 yahoo
# borisjua                                                    gmail
# borisjua                                                    gmail
# borisjua                                                    gmail
# boto_stm                                                    hotmail
# bozo_lp_2                                                   yahoo
# br88jp                                                      gmail
# braeckevelt                                                 pandora
# braiannunes                                                 yahoo
# braiannunes                                                 yahoo
# brainstorming.br                                            gmail
# brancogoval                                                 hotmail
# brandynho__2007                                             hotmail
# Brasil.Naruto                                               gmail
# brawnzinho                                                  hotmail
# brawnzinho                                                  hotmail
# brawnzinho                                                  hotmail
# brayanphillcard                                             hotmail
# brenda.pink                                                 hotmail
# brenda.pink                                                 hotmail
# brenda_msn                                                  hotmail
# brendavalente7                                              yahoo
# brendavalente7                                              yahoo
# ...
# vitorsr92                                                   hotmail
# vitortabombado                                              hotmail
# vitortabombado                                              hotmail
# viuvinha_sozinha                                            hotmail
# viver_sem_amor                                              hotmail
# vivi.almeida1                                               yahoo
# vivi_hta.kiki                                               yahoo
# vivi_marvelous                                              hotmail
# vivi_stockell                                               hotmail
# viviamorim7                                                 hotmail
# vivianegm2                                                  hotmail
# vivianegm2                                                  hotmail
# vivianemelloptu                                             gmail
# vivianemv2                                                  yahoo
# vivianetop                                                  hotmail
# vividonde                                                   gmail
# VIVIKAGREENEYES                                             HOTMAIL
# VIVIKAGREENEYES                                             HOTMAIL
# VIVIKAGREENEYES                                             HOTMAIL
# vivisoapronto_demais                                        hotmail
# vivisuetham                                                 yahoo
# vivitamyris                                                 hotmail
# vivitamyris                                                 hotmail
# vivitamyris                                                 hotmail
# vivsweet_4                                                  hotmail
# vladinhoqueiroz                                             uol
# vladinhoqueiroz                                             uol
# vladinhoqueirozsejas                                        gmail
# vladinhoqueirozsejas                                        gmail
# vladisejas                                                  gmail
# vlamber                                                     hotmail
# vmarap                                                      hotmail
# vmarap                                                      hotmail
# vmarap                                                      hotmail
# vmrocha5                                                    yahoo
# vonega                                                      itelefonica
# voodoothedoll                                               gmail
# vulcan_300                                                  pop
# w.isl                                                       hotmail
# w.isl                                                       hotmail
# w.isl                                                       hotmail
# w.nill02                                                    gmail
# w_batistello                                                hotmail
# wag17capoeira                                               yahoo
# wagner_32                                                   hotmail
# wagnersilvanet                                              gmail
# waitefilipes                                                yaroo
# walcy_zem                                                   yahoo
# walfritjs                                                   hotmail
# walison_r10                                                 yahoo
# walison_r10                                                 yahoo
# walison_r10                                                 yahoo
# walison_r10                                                 yahoo
# walison_so_pras_mina                                        yahoo
# wallacenokia                                                hotmail
# wallacepety                                                 gmail
# wallacepety                                                 gmail
# wallacepety                                                 bol
# wallacepety                                                 gmail
# walter-viana                                                hotmail
# wander_siqueira08                                           hotmail
# wander_siqueira08                                           hotmail
# wander_siqueira08                                           hotmail
# wander_siqueira08                                           hotmail
# wanderson                                                   univale
# wanderson10sp                                               gmail
# wanderson10sp                                               gmail
# wanessaagatha                                               hotmail
# wanessazatta                                                hotmail
# Wang                                                        Pandora
# warlen38                                                    hotmail
# warlenandrade                                               hotmail
# warleytavares                                               yahoo
# weberpdr                                                    yahoo
# wedersonkralho                                              yahoo
# welidavaleska                                               yahoo
# welidavalessa                                               yahoo
# well_promiscuos_boy                                         hotmail
# well_promiscuos_boy                                         hotmail
# well_promiscuos_boy                                         hotmail
# well_promiscuos_boy                                         hotmail
# well_promiscuos_boy                                         hotmail
# well_promiscuos_boy                                         hotmail
# wellek_28                                                   hotmail
# wellintoceara                                               yahoo
# wellinton_16                                                hotmail
# wendel_castelano                                            yahoo
# wendel_ths                                                  hotmail
# wendell.campos                                              hotmail
# wendell_tete_22                                             yahoo
# wendell-cardoso                                             bol
# wendelsantos                                                ajato
# werneckmario                                                yahoo
# werneckmario                                                yahoo
# werneckmario                                                yahoo
# we-rodrigues                                                bol
# wesdley16                                                   hotmail
# wesley.xxx                                                  bol
# wesley_canalha                                              hotmail
# wesley_canalha                                              hotmail
# wesley_canalha                                              hotmail
# wesley_gatinho2                                             msn
# wesley_gatinho2                                             msn
# wesleydub808                                                yahoo
# wesleydub808                                                yahoo
# wesleyfcruz                                                 ig
# wesleyfio                                                   gmail
# wesleyfio                                                   gmail
# wesleymarttins                                              yahoo
# weslleyssf                                                  uol
# weslleyssf                                                  hotmail
# weslley-vl                                                  hotmail
# weslley-vl                                                  hotmail
# wevertoncambraia                                            yahoo
# wevertoncherigati                                           yahoo
# wevertonclone                                               gmail
# weydy.luck.manhosa                                          hotmail
# whiara_gatinha                                              oi
# wil_yuri                                                    hotmail
# wildcat8426                                                 yahoo
# wildersoares                                                hotmail
# wildersoares                                                hotmail
# wilhan_keven14                                              hotmail
# will.flowers89                                              gmail
# will_diogenes                                               yahoo
# willdug                                                     gmail
# willi.teles                                                 yahoo
# william_tize                                                yahoo
# william-badhot                                              hotmail
# williamcomputadores                                         yahoo
# williamdmais                                                hotmail
# williamgates_III                                            hotmail
# williamkoga                                                 gmail
# william-zoinho                                              hotmail
# willianamorimboss                                           yahoo
# williane_kelly                                              yahoo
# willianfonseca3                                             hotmail
# willianluis00                                               hotmail
# williansbeck                                                hotmail
# wilton_aloha                                                gmail
# winnycarol                                                  yahoo
# witineyzinha                                                yahoo
# wkacronem                                                   gmail
# wobersontribalista_                                         hotmail
# wobersontribalista_                                         hotmail
# wobersontribalista_                                         hotmail
# wsbariatty                                                  oi
# wsomacauba                                                  hotmail
# wsomacauba                                                  hotmail
# wtozei                                                      yahoo
# wtsalehouse                                                 yahoo
# wu                                                          wu
# wu                                                          wu
# wwil_flogao                                                 hotmail
# wwwinicius                                                  hotmail
# wwwinicius                                                  hotmail
# wyllergatinho                                               hotmail
# x3ramiro                                                    hotmail
# xandepimentel                                               hotmail
# xandicampello                                               hotmail
# xandyrf                                                     gmail
# xdany_nick                                                  hotmail
# xdiegopgd                                                   yahoo
# xdom_05                                                     yahoo
# xdorkut                                                     yahoo
# xeh_03                                                      hotmail
# xelynha11                                                   hotmail
# xguttix                                                     hotmail
# xiaoxiaofloodma                                             gmail
# xiaoxiaofloodma                                             gmail
# xiaoxiaofloodma                                             gmail
# xiaoxiaofloodma                                             gmail
# xiaoxiaofloodma                                             gmail
# xiaoxiaofloodma                                             gmail
# xinho_fcb                                                   yahoo
# xis_jesus                                                   zipmail
# xixicocobumbum                                              yahoo
# xiznine                                                     gmail
# xiznine                                                     gmail
# xorias_msjgf                                                hotmail
# xoxo9811                                                    hotmail
# xpa_thi                                                     hotmail
# xthomasx_rawwwwwr                                           mississippi
# xuxinhagata                                                 hotmail
# xxxlelexxx                                                  hotmail
# xygers                                                      gmail
# xzibet                                                      gmail
# yago.salathiel                                              yahoo
# yaguinho_bdl                                                hotmail
# yara_sanka                                                  hotmail
# yara_sanka                                                  hotmail
# yara_sanka                                                  hotmail
# yarabya                                                     yahoo
# yasminjf                                                    gmail
# ycaro90                                                     gmail
# yellow_boy_13                                               hotmail
# ygornobrega                                                 gmail
# ygornobrega                                                 gmail
# ygornobrega                                                 gmail
# yrlla_mendes                                                hotmail
# ytalogv12                                                   gmail
# yunnapatricia                                               hotmail
# yuri_costa200                                               hotmail
# yuri_costa200                                               hotmail
# yuri_quintino                                               hotmail
# yuri_smuf                                                   hotmail
# Yuri_terro_x                                                yahoo
# Yuri_terro_x                                                yahoo
# Yuri_terro_x                                                yahoo
# yuri_terro-x                                                hotmail
# yuri_terro-x                                                hotmail
# yuri_terro-x                                                hotmail
# yuri1ar                                                     gmail
# yuriii_df                                                   hotmail
# yurilokko                                                   bol
# yusuke_manabu                                               zipmail
# yutaksjdvsa                                                 hotmail
# yweksler                                                    yahoo
# yzael_junior                                                yahoo
# yzael_junior                                                yahoo
# z7karoom7z                                                  hotmail
# Zac_efron_hsm_brasil                                        hotmail
# zanguief_tora                                               yahoo
# zebedeudecrato                                              hotmail
# zeh_pikao                                                   yahoo
# zelooko                                                     yahoo
# zenilda_peres                                               hotmail
# zettifake                                                   gmail
# zettifake                                                   gmail
# zettifake                                                   gmail
# zettifake                                                   gmail
# zettifake                                                   gmail
# zezin_joe                                                   yahoo
# zim.hac                                                     hotmail
# zizidocinho                                                 yahoo
# zogas3                                                      yahoo
# zoiandu                                                     gmail
# zuy.oliveira                                                hotmail
# zwxzwx1..1                                                  hotmail

# %% [markdown]
# ## E4.4
# Dadas o arquivo de emails anterior, conte quantos emails de cada domínio há na lista de emails.
#
# Dica: utilize os conceitos de estruturas de repetição e estruturas de dados dos capítulos anteriores.

# %%
dominios = []

for email in resposta:
    dominios.append(email[1])

# %%
tipos_de_dominio = list(set(dominios)) #eliminamos duplicatas
len(tipos_de_dominio)
# Out:
# 131

# %%
# contar quantidade de dominios

for dominio in tipos_de_dominio:
    quantidadeDominios = dominios.count(dominio)

    if quantidadeDominios > 10: # filtro
        print(f'{dominio} = {quantidadeDominios}')
# Out:
# HOTMAIL = 24
# uol = 28
# pop = 15
# bol = 410
# msn = 36
# hotmail = 3173
# yahoo = 1895
# zipmail = 12
# ibest = 12
# ig = 59
# terra = 31
# oi = 35
# itelefonica = 11
# walla = 11
# jim = 16
# YAHOO = 24
# gmail = 879

# %% [markdown]
# # Projetos

# %% [markdown]
# ## P4.1
# Crie um script que importe o arquivo de emails e em seguida exporte um arquivo contendo um relatório dos domínios e também com todos os emails.

# %%
import moviepy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2940/2035713447.py in <module>
# ----> 1 import moviepy
#
# ModuleNotFoundError: No module named 'moviepy'
