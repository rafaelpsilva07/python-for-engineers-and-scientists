# %% [markdown]
# # PART 1
# # Section 7: Handling Texts and Files

# %% [markdown]
# ## 7.1 - String Operations
#
# <br/>
#
# Some characteristics of strings are:
# - [x] Accept mathematical operations
# - [x] Are indexable (slicing)
# - [x] Are iterable
# - [x] Accept special formatting
# - [x] Backslashes (\\) are used in special cases

# %%
a = 'Python '

# %%
a * 10
# Out:
# 'Python Python Python Python Python Python Python Python Python Python '

# %%
b = "Python is nice!"

# %%
b[4:7]
# Out:
# 'on '

# %%
list(b)
# Out:
# ['P', 'y', 't', 'h', 'o', 'n', ' ', 'i', 's', ' ', 'n', 'i', 'c', 'e', '!']

# %%
for i in b:
    print(i)
# Out:
# P
# y
# t
# h
# o
# n
#
# i
# s
#
# n
# i
# c
# e
# !

# %%
b
# Out:
# 'Python is nice!'

# %%
age = 32

f'Rafael is {age} years old'
# Out:
# 'Rafael is 32 years old'

# %%
print("This is my first sentence.\n 'I \" want to break a line before that sentence")
# Out:
# This is my first sentence.
#  'I " want to break a line before that sentence

# %% [markdown]
# ## 7.2 - String Methods
#
# <br/>
#
# **Some string manipulation methods:**
#
# <br/>
#
# | Method | Description |
# | :-- | :-- |
# | upper() | Returns uppercase letters |
# | lower() | Returns lowercase letters |
# | replace(arg_old, arg_new) | Replaces arg_old with arg_new |
# | find(arg)| Returns the position of the first occurrence. Note: rfind() |
# | strip() | Returns a string removing leading and trailing whitespace characters. Note: rstrip(), lstrip() |
# | count() | Returns the number of occurrences of an item. |
# | split(arg) | Returns a list where elements are separated by the input argument |
# | isupper() | Checks if all characters are uppercase and returns a boolean. Note: islower(), isalpha(), isnumeric() |
# | startswith(arg) | Checks if the string starts with arg. Note: endswith() |
#
# <br/>
#
# **Note:**
# <pre>It's always important to check how the method you're using acts on the object. In this case, the methods do not modify the object, as strings are immutable.</pre>

# %%
a = 'PytHon'

# %%
a = a.lower()

# %%
a = a.upper()

# %%
b = 'HelloPWorld!PImPhere'

# %%
b = b.replace('P', ' ')

# %%
b
# Out:
# 'Hello World! Im here'

# %%
b.rfind('l')
# Out:
# 9

# %%
b[10]
# Out:
# 'd'

# %%
c = '    Python is nice   '

# %%
c = c.strip()

# %%
c.split('n')
# Out:
# ['Pytho', ' is ', 'ice']

# %%
c.isupper()
# Out:
# False

# %%
b
# Out:
# 'Hello World! Im here'

# %%
b.startswith('H')
# Out:
# True

# %%
b.endswith('e')
# Out:
# True

# %% [markdown]
# ## 7.3 - String Formatting
#
# <br/>
#
# Starting from Python 3.6, f-strings were added, which make string formatting easier. If you are using an earlier version of Python, there are other ways to format strings such as the format() method or %.
#
# <br/>
#
# #### Syntax of f-strings
#
# ```python
# >>> result = 10
# >>> text_result = f'Result = {result}'
# >>> pi = 3.14159
# >>> pi_value = f'The value of pi is {pi: .2f}'
# ```
#
# <br/>
#
# **Note:**
# <pre>In addition to f-strings, there are other prefixes that can be used: r for raw, b for binary, and u for unicode.</pre>

# %%
number = 20


a = f'ten times two is equal to {20}'

# %%
a
# Out:
# 'ten times two is equal to 20'

# %%
c = 1 / 3
c
# Out:
# 0.3333333333333333

# %%
f'One divided by three is equal to {c: .2f}'
# Out:
# 'One divided by three is equal to  0.33'

# %%
path = b'\path\folder1\folder2\file.ext \n line breaker'
print(path)
# Out:
# b'\\path\x0colder1\x0colder2\x0cile.ext \n line breaker'

# %% [markdown]
# ## 7.4 - Reading and Writing Files
#
# <br/>
#
# Reading and writing files is a great way to automate tasks in science and engineering. However, we must do this correctly to avoid leaving the file open without our knowledge. To avoid this risk, use the **with** statement.
#
# #### Syntax of f-strings
#
# ```python
# >>> path = 'C:/....'
# >>> with open(path, 'r') as f:
# >>>     content = f.read()
# >>> print(content)
# ```
#
# **Notes:**
#
# <pre>Parameters:
# - 'r': read
# - 'w': write
# - 'wb': write binary</pre>
#
# <pre>Methods:
# - read(): reads the content of the file and returns a string
# - readlines(): reads the content of the file and returns a list</pre>

# %%
path = r'D:\repositories\python-for-engineers-and-scientists\Aux_files\7.4\equipement_data.txt'
with open(path, 'r') as f:
    content = f.readlines()

# %%
len(content)
# Out:
# 16

# %%
content
# Out:
# ['Date,Equipment ID,Temperature (°C),Pressure (bar),Flow Rate (m³/h),Efficiency (%),Operating Hours\n',
#  '2024-05-01,EQ-001,75.2,15.3,120.5,88.6,8.0\n',
#  '2024-05-02,EQ-001,76.8,15.7,122.0,89.1,7.5\n',
#  '2024-05-03,EQ-001,74.5,15.1,119.8,87.9,8.5\n',
#  '2024-05-04,EQ-002,80.3,16.2,130.7,91.2,6.0\n',
#  '2024-05-05,EQ-002,79.5,16.0,128.4,90.8,6.5\n',
#  '2024-05-06,EQ-002,81.0,16.5,132.1,91.5,5.5\n',
#  '2024-05-07,EQ-003,78.2,15.5,125.6,89.5,7.0\n',
#  '2024-05-08,EQ-003,77.6,15.4,124.8,89.0,7.2\n',
#  '2024-05-09,EQ-003,79.0,15.8,126.3,90.1,6.8\n',
#  '2024-05-10,EQ-004,73.5,14.8,118.2,87.0,8.2\n',
#  '2024-05-11,EQ-004,74.1,15.0,119.0,87.3,8.0\n',
#  '2024-05-12,EQ-004,72.8,14.6,117.5,86.8,8.3\n',
#  '2024-05-13,EQ-005,82.3,16.8,135.2,92.0,5.0\n',
#  '2024-05-14,EQ-005,83.0,17.0,136.5,92.3,4.8\n',
#  '2024-05-15,EQ-005,81.7,16.7,134.0,91.8,5.2']

# %%
content = content[0:15]

# %%
content.append('2024-05-15,EQ-005,81.7,16.7,134.0,91.8,5.2\n')
content.append('2024-05-15,EQ-005,81.7,16.7,134.0,120,24')

# %%
content
# Out:
# ['Date,Equipment ID,Temperature (°C),Pressure (bar),Flow Rate (m³/h),Efficiency (%),Operating Hours\n',
#  '2024-05-01,EQ-001,75.2,15.3,120.5,88.6,8.0\n',
#  '2024-05-02,EQ-001,76.8,15.7,122.0,89.1,7.5\n',
#  '2024-05-03,EQ-001,74.5,15.1,119.8,87.9,8.5\n',
#  '2024-05-04,EQ-002,80.3,16.2,130.7,91.2,6.0\n',
#  '2024-05-05,EQ-002,79.5,16.0,128.4,90.8,6.5\n',
#  '2024-05-06,EQ-002,81.0,16.5,132.1,91.5,5.5\n',
#  '2024-05-07,EQ-003,78.2,15.5,125.6,89.5,7.0\n',
#  '2024-05-08,EQ-003,77.6,15.4,124.8,89.0,7.2\n',
#  '2024-05-09,EQ-003,79.0,15.8,126.3,90.1,6.8\n',
#  '2024-05-10,EQ-004,73.5,14.8,118.2,87.0,8.2\n',
#  '2024-05-11,EQ-004,74.1,15.0,119.0,87.3,8.0\n',
#  '2024-05-12,EQ-004,72.8,14.6,117.5,86.8,8.3\n',
#  '2024-05-13,EQ-005,82.3,16.8,135.2,92.0,5.0\n',
#  '2024-05-14,EQ-005,83.0,17.0,136.5,92.3,4.8\n',
#  '2024-05-15,EQ-005,81.7,16.7,134.0,91.8,5.2\n',
#  '2024-05-15,EQ-005,81.7,16.7,134.0,120,24']

# %%
result = ''
for line in content:
    result += line

# %%
path2 = r'D:\repositories\python-for-engineers-and-scientists\Aux_files\7.4\equipement_data2.txt'
with open(path2, 'w') as f:
    f.write(result)

# %% [markdown]
# ## 7.5 - Encoding
#
# <br/>
#
# Simply put, encoding is a conversion table from binary format to text format.
#
# <br/>
#
# #### Examples
#
#
# | UTF-8                      | ANSI       | ASCII     | Character |
# | ------------------------- | ---------- | --------- | --------- |
# | 01000001 (41)             | 01000001   | 01000001  | A         |
# | 01011010 (5A)             | 01011010   | 01011010  | Z         |
# | 01100001 (61)             | 01100001   | 01100001  | a         |
# | 01111010 (7A)             | 01111010   | 01111010  | z         |
# | 11000011 10100001 (C3 A1) | 11100001   | --        | á         |
# | 11000011 10000001 (C3 81) | 11000001   | --        | Á         |
#
#
#
# <br/>
#
# **Note:**
# <pre>ASCII is formed with 1 byte (8 bits), with the first number not being used, so the table has 128 values. This table does not include accents.</pre>
# <pre>ANSI is formed with 1 byte (8 bits), it has 256 values. It contains all those from ASCII plus others including accents.</pre>
# <pre>UTF-8 uses a multibyte concept. The first 128 characters are from ASCII. As demand for special characters increases, more bytes are included. The UTF-8 consortium contains over a million characters and some of them can be up to 3 bytes.</pre>
#
# <br/>

# %%
def binaryToDecimal(n):
    return int(n, 2)

# %%
hex(binaryToDecimal('10000001'))
# Out:
# '0x81'

# %%
a = 'á'

a.encode(encoding='UTF-8')
# Out:
# b'\xc3\xa1'

# %% [markdown]
# # Exercises

# %% [markdown]
# ## E7.1
# Given any email, ```example@gmail.com```, return a list with the username and the domain.
#
# Output:
#
# ```
# [example, gmail]
# ```

# %%
email = 'rafael@gmail.com'

# %%
email_format = email.split('@')

# %%
email_format[1] = email_format[1].split('.')[0]

# %%
email_format
# Out:
# ['rafael', 'gmail']

# %%
def split_email(email):
    email_format = email.split('@')
    email_format[1] = email_format[1].split('.')[0]
    return email_format

# %%
split_email(email)
# Out:
# ['rafael', 'gmail']

# %% [markdown]
# ## E7.2
# Given a file with emails, return a list with the usernames and domains.
#
# Suggested data format:
# ```python
# email_list = [[username1, domain1],
#               [username2, domain2],
#               [usernamen, domainn]
#              ]
# ```

# %%
path = r'D:\repositories\python-for-engineers-and-scientists\Aux_files\E7.2\emails.txt'
with open(path, 'r') as f:
    emails = f.readlines()

# %%
len(emails)
# Out:
# 1000

# %%
def split_email(email):
    email_format = email.split('@')
    email_format[1] = email_format[1].split('.')[0]
    return email_format

# %%
emails_format = []
for email in emails:
    emails_format.append(
        split_email(email)
    )

# %%
emails_format
# Out:
# [['jessica.thomas', 'quantumbridge'],
#  ['thomas.martinez', 'solarflare'],
#  ['mary.miller', 'quantumbridge'],
#  ['robert.jones', 'techsparkle'],
#  ['elizabeth.martinez', 'digitaldawn'],
#  ['robert.anderson', 'greengrove'],
#  ['william.smith', 'digitaldawn'],
#  ['thomas.davis', 'digitaldawn'],
#  ['linda.wilson', 'quantumbridge'],
#  ['mary.williams', 'bluestream'],
#  ['susan.davis', 'greengrove'],
#  ['robert.miller', 'riverbend'],
#  ['david.miller', 'riverbend'],
#  ['patricia.rodriguez', 'echovalley'],
#  ['patricia.johnson', 'digitaldawn'],
#  ['patricia.martinez', 'bluestream'],
#  ['mary.davis', 'echovalley'],
#  ['linda.miller', 'riverbend'],
#  ['john.martinez', 'solarflare'],
#  ['mary.thomas', 'techsparkle'],
#  ['mary.wilson', 'riverbend'],
#  ['robert.wilson', 'greengrove'],
#  ['thomas.jones', 'quantumbridge'],
#  ['linda.smith', 'bluestream'],
#  ['jessica.moore', 'bluestream'],
#  ['elizabeth.thomas', 'bluestream'],
#  ['thomas.thomas', 'digitaldawn'],
#  ['jennifer.brown', 'bluestream'],
#  ['michael.moore', 'bluestream'],
#  ['john.thomas', 'techsparkle'],
#  ['john.davis', 'echovalley'],
#  ['robert.johnson', 'echovalley'],
#  ['elizabeth.moore', 'greengrove'],
#  ['susan.wilson', 'bluestream'],
#  ['jessica.johnson', 'techsparkle'],
#  ['jennifer.anderson', 'techsparkle'],
#  ['jennifer.smith', 'digitaldawn'],
#  ['thomas.anderson', 'echovalley'],
#  ['susan.brown', 'riverbend'],
#  ['thomas.brown', 'echovalley'],
#  ['barbara.johnson', 'quantumbridge'],
#  ['jessica.martinez', 'techsparkle'],
#  ['susan.hernandez', 'greengrove'],
#  ['jennifer.thomas', 'greengrove'],
#  ['jessica.wilson', 'riverbend'],
#  ['robert.moore', 'riverbend'],
#  ['linda.miller', 'bluestream'],
#  ['linda.garcia', 'techsparkle'],
#  ['elizabeth.thomas', 'digitaldawn'],
#  ['susan.davis', 'riverbend'],
#  ['patricia.williams', 'quantumbridge'],
#  ['james.garcia', 'solarflare'],
#  ['john.anderson', 'greengrove'],
#  ['thomas.taylor', 'greengrove'],
#  ['patricia.wilson', 'digitaldawn'],
#  ['mary.miller', 'quantumbridge'],
#  ['linda.thomas', 'riverbend'],
#  ['michael.davis', 'techsparkle'],
#  ['john.moore', 'bluestream'],
#  ['michael.rodriguez', 'bluestream'],
#  ['susan.anderson', 'techsparkle'],
#  ['john.johnson', 'digitaldawn'],
#  ['michael.thomas', 'echovalley'],
#  ['thomas.brown', 'solarflare'],
#  ['david.johnson', 'echovalley'],
#  ['linda.davis', 'solarflare'],
#  ['patricia.garcia', 'riverbend'],
#  ['robert.rodriguez', 'bluestream'],
#  ['david.davis', 'digitaldawn'],
#  ['elizabeth.wilson', 'echovalley'],
#  ['william.anderson', 'digitaldawn'],
#  ['mary.davis', 'techsparkle'],
#  ['james.miller', 'bluestream'],
#  ['william.jones', 'greengrove'],
#  ['thomas.garcia', 'riverbend'],
#  ['robert.brown', 'quantumbridge'],
#  ['thomas.williams', 'riverbend'],
#  ['elizabeth.garcia', 'bluestream'],
#  ['james.jones', 'echovalley'],
#  ['jennifer.taylor', 'greengrove'],
#  ['robert.brown', 'riverbend'],
#  ['barbara.smith', 'quantumbridge'],
#  ['john.miller', 'quantumbridge'],
#  ['david.thomas', 'quantumbridge'],
#  ['thomas.moore', 'riverbend'],
#  ['linda.anderson', 'digitaldawn'],
#  ['patricia.martinez', 'greengrove'],
#  ['william.taylor', 'echovalley'],
#  ['robert.smith', 'echovalley'],
#  ['james.johnson', 'riverbend'],
#  ['mary.thomas', 'bluestream'],
#  ['michael.taylor', 'solarflare'],
#  ['joseph.davis', 'quantumbridge'],
#  ['susan.miller', 'echovalley'],
#  ['linda.williams', 'echovalley'],
#  ['jessica.martinez', 'digitaldawn'],
#  ['mary.jones', 'greengrove'],
#  ['linda.miller', 'greengrove'],
#  ['jennifer.rodriguez', 'solarflare'],
#  ['mary.garcia', 'quantumbridge'],
#  ['robert.wilson', 'echovalley'],
#  ['john.rodriguez', 'bluestream'],
#  ['robert.rodriguez', 'bluestream'],
#  ['william.garcia', 'bluestream'],
#  ['barbara.thomas', 'techsparkle'],
#  ['thomas.brown', 'greengrove'],
#  ['david.rodriguez', 'riverbend'],
#  ['thomas.anderson', 'echovalley'],
#  ['james.brown', 'bluestream'],
#  ['elizabeth.hernandez', 'quantumbridge'],
#  ['jennifer.williams', 'quantumbridge'],
#  ['robert.miller', 'solarflare'],
#  ['susan.moore', 'solarflare'],
#  ['thomas.martinez', 'echovalley'],
#  ['michael.williams', 'techsparkle'],
#  ['jennifer.thomas', 'digitaldawn'],
#  ['patricia.rodriguez', 'techsparkle'],
#  ['jennifer.smith', 'quantumbridge'],
#  ['jennifer.martinez', 'digitaldawn'],
#  ['mary.garcia', 'quantumbridge'],
#  ['mary.miller', 'solarflare'],
#  ['jennifer.garcia', 'greengrove'],
#  ['david.thomas', 'solarflare'],
#  ['patricia.hernandez', 'digitaldawn'],
#  ['thomas.martinez', 'solarflare'],
#  ['joseph.smith', 'echovalley'],
#  ['robert.wilson', 'digitaldawn'],
#  ['barbara.williams', 'echovalley'],
#  ['william.brown', 'greengrove'],
#  ['linda.smith', 'riverbend'],
#  ['jennifer.brown', 'bluestream'],
#  ['jennifer.taylor', 'greengrove'],
#  ['patricia.moore', 'solarflare'],
#  ['patricia.garcia', 'bluestream'],
#  ['mary.jones', 'greengrove'],
#  ['michael.garcia', 'solarflare'],
#  ['barbara.brown', 'solarflare'],
#  ['joseph.wilson', 'solarflare'],
#  ['john.garcia', 'solarflare'],
#  ['mary.rodriguez', 'riverbend'],
#  ['james.johnson', 'riverbend'],
#  ['thomas.martinez', 'digitaldawn'],
#  ['john.anderson', 'greengrove'],
#  ['joseph.brown', 'digitaldawn'],
#  ['william.moore', 'greengrove'],
#  ['mary.smith', 'digitaldawn'],
#  ['elizabeth.garcia', 'riverbend'],
#  ['susan.garcia', 'digitaldawn'],
#  ['robert.miller', 'solarflare'],
#  ['robert.johnson', 'echovalley'],
#  ['susan.smith', 'echovalley'],
#  ['john.williams', 'techsparkle'],
#  ['william.brown', 'quantumbridge'],
#  ['robert.rodriguez', 'quantumbridge'],
#  ['jennifer.thomas', 'echovalley'],
#  ['barbara.taylor', 'echovalley'],
#  ['robert.rodriguez', 'digitaldawn'],
#  ['michael.anderson', 'bluestream'],
#  ['mary.brown', 'digitaldawn'],
#  ['robert.williams', 'quantumbridge'],
#  ['patricia.martinez', 'riverbend'],
#  ['michael.rodriguez', 'echovalley'],
#  ['barbara.hernandez', 'digitaldawn'],
#  ['thomas.thomas', 'digitaldawn'],
#  ['jessica.hernandez', 'techsparkle'],
#  ['david.taylor', 'solarflare'],
#  ['james.moore', 'techsparkle'],
#  ['jessica.taylor', 'digitaldawn'],
#  ['joseph.wilson', 'echovalley'],
#  ['john.thomas', 'digitaldawn'],
#  ['robert.hernandez', 'digitaldawn'],
#  ['michael.johnson', 'techsparkle'],
#  ['mary.taylor', 'solarflare'],
#  ['elizabeth.miller', 'greengrove'],
#  ['patricia.davis', 'quantumbridge'],
#  ['patricia.thomas', 'greengrove'],
#  ['david.martinez', 'greengrove'],
#  ['robert.brown', 'riverbend'],
#  ['thomas.brown', 'riverbend'],
#  ['elizabeth.hernandez', 'riverbend'],
#  ['jennifer.taylor', 'techsparkle'],
#  ['barbara.moore', 'bluestream'],
#  ['jessica.garcia', 'quantumbridge'],
#  ['robert.anderson', 'solarflare'],
#  ['susan.brown', 'echovalley'],
#  ['robert.johnson', 'riverbend'],
#  ['jennifer.hernandez', 'techsparkle'],
#  ['barbara.johnson', 'quantumbridge'],
#  ['jessica.davis', 'greengrove'],
#  ['joseph.taylor', 'techsparkle'],
#  ['william.smith', 'riverbend'],
#  ['joseph.thomas', 'quantumbridge'],
#  ['thomas.wilson', 'solarflare'],
#  ['william.thomas', 'solarflare'],
#  ['john.hernandez', 'solarflare'],
#  ['michael.martinez', 'bluestream'],
#  ['patricia.anderson', 'greengrove'],
#  ['michael.garcia', 'greengrove'],
#  ['susan.davis', 'greengrove'],
#  ['elizabeth.anderson', 'echovalley'],
#  ['elizabeth.garcia', 'echovalley'],
#  ['michael.garcia', 'riverbend'],
#  ['barbara.miller', 'echovalley'],
#  ['robert.moore', 'echovalley'],
#  ['michael.davis', 'greengrove'],
#  ['jennifer.taylor', 'quantumbridge'],
#  ['jennifer.smith', 'quantumbridge'],
#  ['joseph.smith', 'quantumbridge'],
#  ['david.taylor', 'digitaldawn'],
#  ['john.garcia', 'quantumbridge'],
#  ['william.davis', 'greengrove'],
#  ['james.johnson', 'techsparkle'],
#  ['barbara.anderson', 'bluestream'],
#  ['linda.smith', 'digitaldawn'],
#  ['patricia.thomas', 'quantumbridge'],
#  ['david.anderson', 'riverbend'],
#  ['john.taylor', 'digitaldawn'],
#  ['john.brown', 'solarflare'],
#  ['jennifer.miller', 'solarflare'],
#  ['elizabeth.anderson', 'bluestream'],
#  ['john.smith', 'techsparkle'],
#  ['susan.thomas', 'greengrove'],
#  ['john.johnson', 'quantumbridge'],
#  ['patricia.davis', 'techsparkle'],
#  ['jessica.anderson', 'techsparkle'],
#  ['elizabeth.rodriguez', 'solarflare'],
#  ['joseph.moore', 'solarflare'],
#  ['susan.davis', 'greengrove'],
#  ['thomas.smith', 'riverbend'],
#  ['mary.thomas', 'quantumbridge'],
#  ['patricia.moore', 'quantumbridge'],
#  ['jennifer.hernandez', 'solarflare'],
#  ['john.davis', 'quantumbridge'],
#  ['patricia.davis', 'greengrove'],
#  ['patricia.hernandez', 'riverbend'],
#  ['david.williams', 'solarflare'],
#  ['michael.martinez', 'greengrove'],
#  ['james.anderson', 'riverbend'],
#  ['james.johnson', 'bluestream'],
#  ['elizabeth.moore', 'bluestream'],
#  ['robert.taylor', 'quantumbridge'],
#  ['barbara.thomas', 'digitaldawn'],
#  ['jessica.smith', 'solarflare'],
#  ['mary.miller', 'digitaldawn'],
#  ['robert.hernandez', 'solarflare'],
#  ['susan.brown', 'digitaldawn'],
#  ['jessica.wilson', 'riverbend'],
#  ['david.thomas', 'greengrove'],
#  ['barbara.taylor', 'riverbend'],
#  ['mary.davis', 'greengrove'],
#  ['joseph.miller', 'riverbend'],
#  ['jessica.taylor', 'techsparkle'],
#  ['john.martinez', 'riverbend'],
#  ['john.moore', 'bluestream'],
#  ['thomas.williams', 'bluestream'],
#  ['jessica.thomas', 'echovalley'],
#  ['john.brown', 'quantumbridge'],
#  ['barbara.martinez', 'echovalley'],
#  ['james.brown', 'quantumbridge'],
#  ['linda.wilson', 'solarflare'],
#  ['jennifer.hernandez', 'digitaldawn'],
#  ['barbara.jones', 'solarflare'],
#  ['mary.moore', 'echovalley'],
#  ['william.davis', 'greengrove'],
#  ['david.brown', 'digitaldawn'],
#  ['john.rodriguez', 'echovalley'],
#  ['david.smith', 'digitaldawn'],
#  ['michael.davis', 'bluestream'],
#  ['john.johnson', 'techsparkle'],
#  ['barbara.martinez', 'digitaldawn'],
#  ['robert.hernandez', 'riverbend'],
#  ['jennifer.martinez', 'techsparkle'],
#  ['mary.moore', 'bluestream'],
#  ['joseph.johnson', 'digitaldawn'],
#  ['jennifer.rodriguez', 'digitaldawn'],
#  ['john.anderson', 'digitaldawn'],
#  ['thomas.anderson', 'solarflare'],
#  ['michael.davis', 'solarflare'],
#  ['elizabeth.hernandez', 'quantumbridge'],
#  ['william.davis', 'quantumbridge'],
#  ['patricia.smith', 'greengrove'],
#  ['thomas.smith', 'riverbend'],
#  ['john.wilson', 'greengrove'],
#  ['robert.thomas', 'greengrove'],
#  ['william.jones', 'bluestream'],
#  ['michael.brown', 'quantumbridge'],
#  ['jennifer.rodriguez', 'digitaldawn'],
#  ['susan.smith', 'digitaldawn'],
#  ['jessica.jones', 'echovalley'],
#  ['barbara.wilson', 'greengrove'],
#  ['barbara.miller', 'solarflare'],
#  ['susan.garcia', 'techsparkle'],
#  ['patricia.taylor', 'techsparkle'],
#  ['jessica.anderson', 'riverbend'],
#  ['jennifer.garcia', 'greengrove'],
#  ['patricia.anderson', 'riverbend'],
#  ['barbara.thomas', 'bluestream'],
#  ['jessica.smith', 'quantumbridge'],
#  ['michael.johnson', 'echovalley'],
#  ['patricia.johnson', 'solarflare'],
#  ['michael.williams', 'solarflare'],
#  ['john.brown', 'solarflare'],
#  ['joseph.taylor', 'greengrove'],
#  ['thomas.garcia', 'riverbend'],
#  ['susan.davis', 'echovalley'],
#  ['david.wilson', 'techsparkle'],
#  ['thomas.rodriguez', 'greengrove'],
#  ['david.anderson', 'digitaldawn'],
#  ['robert.moore', 'quantumbridge'],
#  ['barbara.moore', 'greengrove'],
#  ['patricia.johnson', 'greengrove'],
#  ['patricia.wilson', 'echovalley'],
#  ['joseph.miller', 'greengrove'],
#  ['thomas.smith', 'techsparkle'],
#  ['mary.garcia', 'greengrove'],
#  ['william.brown', 'quantumbridge'],
#  ['jessica.anderson', 'greengrove'],
#  ['linda.taylor', 'digitaldawn'],
#  ['linda.martinez', 'greengrove'],
#  ['john.williams', 'riverbend'],
#  ['james.moore', 'echovalley'],
#  ['robert.wilson', 'quantumbridge'],
#  ['robert.garcia', 'echovalley'],
#  ['jessica.martinez', 'techsparkle'],
#  ['jennifer.moore', 'riverbend'],
#  ['mary.davis', 'echovalley'],
#  ['mary.johnson', 'techsparkle'],
#  ['david.moore', 'digitaldawn'],
#  ['elizabeth.jones', 'quantumbridge'],
#  ['david.jones', 'echovalley'],
#  ['susan.moore', 'digitaldawn'],
#  ['barbara.taylor', 'bluestream'],
#  ['james.jones', 'greengrove'],
#  ['robert.moore', 'quantumbridge'],
#  ['jessica.smith', 'solarflare'],
#  ['elizabeth.wilson', 'echovalley'],
#  ['john.taylor', 'solarflare'],
#  ['david.rodriguez', 'greengrove'],
#  ['thomas.davis', 'greengrove'],
#  ['jennifer.rodriguez', 'digitaldawn'],
#  ['david.miller', 'riverbend'],
#  ['michael.smith', 'quantumbridge'],
#  ['susan.hernandez', 'techsparkle'],
#  ['james.johnson', 'riverbend'],
#  ['james.thomas', 'techsparkle'],
#  ['joseph.anderson', 'greengrove'],
#  ['joseph.hernandez', 'solarflare'],
#  ['patricia.wilson', 'greengrove'],
#  ['david.miller', 'bluestream'],
#  ['david.williams', 'quantumbridge'],
#  ['william.johnson', 'greengrove'],
#  ['susan.jones', 'techsparkle'],
#  ['david.moore', 'greengrove'],
#  ['patricia.martinez', 'bluestream'],
#  ['james.thomas', 'solarflare'],
#  ['linda.martinez', 'riverbend'],
#  ['david.rodriguez', 'echovalley'],
#  ['joseph.brown', 'riverbend'],
#  ['james.wilson', 'techsparkle'],
#  ['patricia.wilson', 'echovalley'],
#  ['james.moore', 'echovalley'],
#  ['jessica.davis', 'digitaldawn'],
#  ['john.moore', 'bluestream'],
#  ['david.anderson', 'solarflare'],
#  ['james.moore', 'quantumbridge'],
#  ['michael.moore', 'riverbend'],
#  ['michael.moore', 'echovalley'],
#  ['john.smith', 'quantumbridge'],
#  ['michael.jones', 'greengrove'],
#  ['david.williams', 'bluestream'],
#  ['joseph.taylor', 'echovalley'],
#  ['william.garcia', 'digitaldawn'],
#  ['elizabeth.brown', 'techsparkle'],
#  ['elizabeth.miller', 'bluestream'],
#  ['barbara.wilson', 'techsparkle'],
#  ['david.jones', 'techsparkle'],
#  ['william.martinez', 'techsparkle'],
#  ['david.garcia', 'echovalley'],
#  ['jessica.martinez', 'riverbend'],
#  ['jessica.brown', 'greengrove'],
#  ['thomas.thomas', 'quantumbridge'],
#  ['thomas.martinez', 'bluestream'],
#  ['jennifer.davis', 'greengrove'],
#  ['jennifer.wilson', 'digitaldawn'],
#  ['jennifer.taylor', 'riverbend'],
#  ['jennifer.anderson', 'quantumbridge'],
#  ['jennifer.garcia', 'greengrove'],
#  ['james.anderson', 'quantumbridge'],
#  ['mary.rodriguez', 'solarflare'],
#  ['patricia.martinez', 'digitaldawn'],
#  ['william.williams', 'digitaldawn'],
#  ['susan.taylor', 'solarflare'],
#  ['mary.smith', 'echovalley'],
#  ['barbara.thomas', 'digitaldawn'],
#  ['jessica.taylor', 'digitaldawn'],
#  ['william.thomas', 'solarflare'],
#  ['william.moore', 'riverbend'],
#  ['barbara.rodriguez', 'digitaldawn'],
#  ['jennifer.brown', 'bluestream'],
#  ['david.johnson', 'techsparkle'],
#  ['jennifer.jones', 'solarflare'],
#  ['robert.wilson', 'greengrove'],
#  ['mary.smith', 'echovalley'],
#  ['susan.taylor', 'digitaldawn'],
#  ['thomas.hernandez', 'greengrove'],
#  ['jessica.williams', 'greengrove'],
#  ['patricia.anderson', 'techsparkle'],
#  ['james.williams', 'bluestream'],
#  ['jessica.thomas', 'riverbend'],
#  ['jessica.moore', 'bluestream'],
#  ['james.johnson', 'greengrove'],
#  ['jessica.moore', 'digitaldawn'],
#  ['elizabeth.thomas', 'riverbend'],
#  ['joseph.anderson', 'bluestream'],
#  ['william.martinez', 'bluestream'],
#  ['thomas.martinez', 'echovalley'],
#  ['linda.miller', 'digitaldawn'],
#  ['linda.brown', 'quantumbridge'],
#  ['mary.rodriguez', 'echovalley'],
#  ['robert.williams', 'echovalley'],
#  ['michael.jones', 'echovalley'],
#  ['jessica.martinez', 'bluestream'],
#  ['jessica.wilson', 'quantumbridge'],
#  ['mary.jones', 'bluestream'],
#  ['robert.johnson', 'greengrove'],
#  ['robert.martinez', 'quantumbridge'],
#  ['jessica.garcia', 'riverbend'],
#  ['john.rodriguez', 'echovalley'],
#  ['robert.rodriguez', 'riverbend'],
#  ['robert.miller', 'solarflare'],
#  ['robert.miller', 'echovalley'],
#  ['robert.johnson', 'solarflare'],
#  ['linda.johnson', 'bluestream'],
#  ['mary.moore', 'echovalley'],
#  ['patricia.smith', 'solarflare'],
#  ['joseph.jones', 'greengrove'],
#  ['james.rodriguez', 'solarflare'],
#  ['john.johnson', 'greengrove'],
#  ['linda.johnson', 'quantumbridge'],
#  ['patricia.smith', 'greengrove'],
#  ['michael.anderson', 'echovalley'],
#  ['elizabeth.garcia', 'digitaldawn'],
#  ['mary.davis', 'bluestream'],
#  ['patricia.miller', 'techsparkle'],
#  ['michael.wilson', 'riverbend'],
#  ['susan.taylor', 'solarflare'],
#  ['patricia.moore', 'digitaldawn'],
#  ['mary.taylor', 'bluestream'],
#  ['david.martinez', 'techsparkle'],
#  ['mary.miller', 'greengrove'],
#  ['william.martinez', 'quantumbridge'],
#  ['susan.taylor', 'quantumbridge'],
#  ['linda.anderson', 'quantumbridge'],
#  ['william.martinez', 'quantumbridge'],
#  ['mary.brown', 'greengrove'],
#  ['john.williams', 'riverbend'],
#  ['susan.moore', 'digitaldawn'],
#  ['joseph.johnson', 'riverbend'],
#  ['robert.garcia', 'quantumbridge'],
#  ['linda.johnson', 'greengrove'],
#  ['barbara.smith', 'greengrove'],
#  ['jennifer.davis', 'bluestream'],
#  ['susan.taylor', 'echovalley'],
#  ['jennifer.miller', 'greengrove'],
#  ['james.moore', 'techsparkle'],
#  ['joseph.thomas', 'techsparkle'],
#  ['susan.rodriguez', 'echovalley'],
#  ['jessica.jones', 'bluestream'],
#  ['james.brown', 'greengrove'],
#  ['joseph.martinez', 'riverbend'],
#  ['joseph.taylor', 'bluestream'],
#  ['susan.anderson', 'techsparkle'],
#  ['jennifer.taylor', 'bluestream'],
#  ['william.taylor', 'echovalley'],
#  ['barbara.jones', 'bluestream'],
#  ['robert.williams', 'greengrove'],
#  ['patricia.anderson', 'greengrove'],
#  ['linda.smith', 'quantumbridge'],
#  ['david.johnson', 'digitaldawn'],
#  ['david.jones', 'bluestream'],
#  ['robert.taylor', 'echovalley'],
#  ['john.hernandez', 'quantumbridge'],
#  ['patricia.davis', 'riverbend'],
#  ['elizabeth.rodriguez', 'digitaldawn'],
#  ['jennifer.hernandez', 'bluestream'],
#  ['patricia.martinez', 'echovalley'],
#  ['linda.smith', 'techsparkle'],
#  ['robert.smith', 'echovalley'],
#  ['michael.jones', 'quantumbridge'],
#  ['thomas.williams', 'greengrove'],
#  ['jessica.thomas', 'quantumbridge'],
#  ['linda.anderson', 'greengrove'],
#  ['elizabeth.williams', 'echovalley'],
#  ['joseph.garcia', 'greengrove'],
#  ['jessica.wilson', 'digitaldawn'],
#  ['joseph.anderson', 'riverbend'],
#  ['michael.hernandez', 'quantumbridge'],
#  ['william.wilson', 'bluestream'],
#  ['jennifer.martinez', 'techsparkle'],
#  ['james.martinez', 'techsparkle'],
#  ['david.taylor', 'quantumbridge'],
#  ['joseph.williams', 'quantumbridge'],
#  ['jessica.williams', 'echovalley'],
#  ['jessica.davis', 'greengrove'],
#  ['michael.moore', 'riverbend'],
#  ['william.miller', 'quantumbridge'],
#  ['john.davis', 'echovalley'],
#  ['jennifer.taylor', 'riverbend'],
#  ['james.johnson', 'digitaldawn'],
#  ['james.hernandez', 'greengrove'],
#  ['jessica.thomas', 'solarflare'],
#  ['david.thomas', 'techsparkle'],
#  ['michael.moore', 'greengrove'],
#  ['david.garcia', 'echovalley'],
#  ['john.davis', 'quantumbridge'],
#  ['william.jones', 'bluestream'],
#  ['robert.thomas', 'greengrove'],
#  ['joseph.taylor', 'digitaldawn'],
#  ['linda.wilson', 'bluestream'],
#  ['patricia.garcia', 'solarflare'],
#  ['michael.johnson', 'echovalley'],
#  ['william.rodriguez', 'greengrove'],
#  ['jennifer.wilson', 'greengrove'],
#  ['joseph.jones', 'techsparkle'],
#  ['linda.rodriguez', 'digitaldawn'],
#  ['linda.williams', 'riverbend'],
#  ['elizabeth.wilson', 'quantumbridge'],
#  ['joseph.brown', 'echovalley'],
#  ['david.davis', 'digitaldawn'],
#  ['linda.johnson', 'digitaldawn'],
#  ['john.johnson', 'echovalley'],
#  ['jennifer.hernandez', 'echovalley'],
#  ['james.taylor', 'riverbend'],
#  ['elizabeth.jones', 'solarflare'],
#  ['joseph.rodriguez', 'digitaldawn'],
#  ['william.taylor', 'greengrove'],
#  ['thomas.anderson', 'quantumbridge'],
#  ['patricia.moore', 'greengrove'],
#  ['mary.thomas', 'greengrove'],
#  ['barbara.moore', 'techsparkle'],
#  ['barbara.jones', 'solarflare'],
#  ['william.smith', 'greengrove'],
#  ['jessica.garcia', 'techsparkle'],
#  ['william.garcia', 'quantumbridge'],
#  ['james.thomas', 'riverbend'],
#  ['susan.hernandez', 'echovalley'],
#  ['jennifer.jones', 'techsparkle'],
#  ['linda.wilson', 'solarflare'],
#  ['patricia.brown', 'riverbend'],
#  ['thomas.garcia', 'digitaldawn'],
#  ['elizabeth.moore', 'bluestream'],
#  ['elizabeth.smith', 'bluestream'],
#  ['robert.williams', 'bluestream'],
#  ['john.johnson', 'techsparkle'],
#  ['michael.brown', 'greengrove'],
#  ['robert.taylor', 'greengrove'],
#  ['susan.miller', 'digitaldawn'],
#  ['james.miller', 'digitaldawn'],
#  ['thomas.rodriguez', 'quantumbridge'],
#  ['david.johnson', 'solarflare'],
#  ['patricia.martinez', 'techsparkle'],
#  ['john.miller', 'echovalley'],
#  ['david.taylor', 'riverbend'],
#  ['barbara.hernandez', 'greengrove'],
#  ['thomas.hernandez', 'riverbend'],
#  ['james.martinez', 'bluestream'],
#  ['linda.rodriguez', 'bluestream'],
#  ['barbara.jones', 'quantumbridge'],
#  ['david.johnson', 'echovalley'],
#  ['linda.smith', 'riverbend'],
#  ['elizabeth.hernandez', 'greengrove'],
#  ['robert.hernandez', 'bluestream'],
#  ['susan.smith', 'quantumbridge'],
#  ['thomas.garcia', 'echovalley'],
#  ['michael.rodriguez', 'techsparkle'],
#  ['susan.brown', 'bluestream'],
#  ['james.martinez', 'digitaldawn'],
#  ['jennifer.taylor', 'bluestream'],
#  ['susan.rodriguez', 'bluestream'],
#  ['joseph.anderson', 'echovalley'],
#  ['james.moore', 'bluestream'],
#  ['jessica.moore', 'riverbend'],
#  ['patricia.moore', 'digitaldawn'],
#  ['michael.garcia', 'greengrove'],
#  ['linda.anderson', 'digitaldawn'],
#  ['robert.moore', 'techsparkle'],
#  ['william.hernandez', 'riverbend'],
#  ['james.wilson', 'solarflare'],
#  ['william.taylor', 'greengrove'],
#  ['elizabeth.williams', 'bluestream'],
#  ['jessica.brown', 'solarflare'],
#  ['david.jones', 'echovalley'],
#  ['robert.rodriguez', 'bluestream'],
#  ['jennifer.johnson', 'quantumbridge'],
#  ['elizabeth.martinez', 'digitaldawn'],
#  ['patricia.miller', 'riverbend'],
#  ['linda.smith', 'greengrove'],
#  ['james.davis', 'riverbend'],
#  ['david.anderson', 'greengrove'],
#  ['robert.johnson', 'techsparkle'],
#  ['robert.anderson', 'bluestream'],
#  ['thomas.jones', 'echovalley'],
#  ['james.anderson', 'echovalley'],
#  ['john.thomas', 'solarflare'],
#  ['robert.hernandez', 'echovalley'],
#  ['thomas.miller', 'quantumbridge'],
#  ['david.miller', 'greengrove'],
#  ['john.martinez', 'bluestream'],
#  ['jessica.martinez', 'echovalley'],
#  ['patricia.wilson', 'quantumbridge'],
#  ['barbara.davis', 'greengrove'],
#  ['thomas.smith', 'solarflare'],
#  ['jessica.smith', 'riverbend'],
#  ['barbara.garcia', 'bluestream'],
#  ['michael.thomas', 'echovalley'],
#  ['john.rodriguez', 'techsparkle'],
#  ['james.thomas', 'riverbend'],
#  ['susan.thomas', 'quantumbridge'],
#  ['linda.williams', 'echovalley'],
#  ['mary.smith', 'solarflare'],
#  ['jennifer.brown', 'greengrove'],
#  ['elizabeth.jones', 'quantumbridge'],
#  ['barbara.miller', 'solarflare'],
#  ['barbara.johnson', 'echovalley'],
#  ['david.brown', 'solarflare'],
#  ['jessica.jones', 'quantumbridge'],
#  ['linda.anderson', 'digitaldawn'],
#  ['michael.wilson', 'echovalley'],
#  ['david.taylor', 'riverbend'],
#  ['william.miller', 'bluestream'],
#  ['elizabeth.hernandez', 'quantumbridge'],
#  ['susan.hernandez', 'techsparkle'],
#  ['michael.moore', 'riverbend'],
#  ['william.jones', 'echovalley'],
#  ['jessica.garcia', 'greengrove'],
#  ['william.wilson', 'greengrove'],
#  ['david.garcia', 'techsparkle'],
#  ['john.miller', 'echovalley'],
#  ['david.davis', 'solarflare'],
#  ['barbara.moore', 'quantumbridge'],
#  ['michael.miller', 'digitaldawn'],
#  ['mary.brown', 'quantumbridge'],
#  ['joseph.rodriguez', 'quantumbridge'],
#  ['jessica.johnson', 'greengrove'],
#  ['jennifer.davis', 'techsparkle'],
#  ['michael.jones', 'quantumbridge'],
#  ['jennifer.moore', 'greengrove'],
#  ['jessica.hernandez', 'solarflare'],
#  ['barbara.garcia', 'echovalley'],
#  ['michael.johnson', 'bluestream'],
#  ['william.williams', 'riverbend'],
#  ['mary.davis', 'quantumbridge'],
#  ['david.jones', 'bluestream'],
#  ['jessica.taylor', 'digitaldawn'],
#  ['thomas.thomas', 'techsparkle'],
#  ['thomas.taylor', 'greengrove'],
#  ['joseph.davis', 'bluestream'],
#  ['patricia.taylor', 'digitaldawn'],
#  ['john.taylor', 'riverbend'],
#  ['thomas.davis', 'techsparkle'],
#  ['james.thomas', 'riverbend'],
#  ['elizabeth.garcia', 'echovalley'],
#  ['elizabeth.thomas', 'quantumbridge'],
#  ['james.williams', 'solarflare'],
#  ['john.thomas', 'digitaldawn'],
#  ['mary.jones', 'solarflare'],
#  ['robert.martinez', 'digitaldawn'],
#  ['john.jones', 'echovalley'],
#  ['john.johnson', 'solarflare'],
#  ['jennifer.hernandez', 'solarflare'],
#  ['john.moore', 'bluestream'],
#  ['mary.martinez', 'quantumbridge'],
#  ['thomas.martinez', 'greengrove'],
#  ['william.garcia', 'solarflare'],
#  ['thomas.hernandez', 'greengrove'],
#  ['john.martinez', 'greengrove'],
#  ['james.moore', 'techsparkle'],
#  ['david.martinez', 'solarflare'],
#  ['david.smith', 'riverbend'],
#  ['john.anderson', 'bluestream'],
#  ['william.brown', 'riverbend'],
#  ['james.martinez', 'digitaldawn'],
#  ['james.williams', 'greengrove'],
#  ['thomas.brown', 'echovalley'],
#  ['william.jones', 'riverbend'],
#  ['elizabeth.rodriguez', 'quantumbridge'],
#  ['james.martinez', 'solarflare'],
#  ['william.davis', 'bluestream'],
#  ['linda.brown', 'digitaldawn'],
#  ['jessica.wilson', 'digitaldawn'],
#  ['jennifer.moore', 'riverbend'],
#  ['david.thomas', 'echovalley'],
#  ['thomas.wilson', 'solarflare'],
#  ['linda.wilson', 'echovalley'],
#  ['robert.moore', 'quantumbridge'],
#  ['thomas.martinez', 'bluestream'],
#  ['linda.miller', 'techsparkle'],
#  ['william.smith', 'echovalley'],
#  ['david.williams', 'echovalley'],
#  ['joseph.miller', 'solarflare'],
#  ['william.moore', 'quantumbridge'],
#  ['mary.hernandez', 'bluestream'],
#  ['joseph.williams', 'quantumbridge'],
#  ['john.davis', 'techsparkle'],
#  ['joseph.moore', 'bluestream'],
#  ['jessica.taylor', 'riverbend'],
#  ['mary.smith', 'digitaldawn'],
#  ['john.davis', 'solarflare'],
#  ['joseph.hernandez', 'solarflare'],
#  ['patricia.moore', 'greengrove'],
#  ['elizabeth.miller', 'solarflare'],
#  ['joseph.johnson', 'quantumbridge'],
#  ['joseph.anderson', 'bluestream'],
#  ['thomas.taylor', 'quantumbridge'],
#  ['barbara.davis', 'solarflare'],
#  ['michael.brown', 'solarflare'],
#  ['elizabeth.rodriguez', 'quantumbridge'],
#  ['thomas.williams', 'bluestream'],
#  ['thomas.moore', 'digitaldawn'],
#  ['barbara.williams', 'greengrove'],
#  ['linda.johnson', 'echovalley'],
#  ['john.wilson', 'bluestream'],
#  ['linda.garcia', 'techsparkle'],
#  ['jennifer.davis', 'riverbend'],
#  ['patricia.miller', 'bluestream'],
#  ['elizabeth.hernandez', 'solarflare'],
#  ['elizabeth.garcia', 'greengrove'],
#  ['james.rodriguez', 'riverbend'],
#  ['linda.hernandez', 'digitaldawn'],
#  ['jennifer.smith', 'greengrove'],
#  ['john.martinez', 'echovalley'],
#  ['michael.miller', 'quantumbridge'],
#  ['elizabeth.moore', 'solarflare'],
#  ['linda.johnson', 'riverbend'],
#  ['mary.jones', 'riverbend'],
#  ['joseph.smith', 'digitaldawn'],
#  ['barbara.taylor', 'riverbend'],
#  ['david.garcia', 'riverbend'],
#  ['thomas.davis', 'bluestream'],
#  ['james.taylor', 'techsparkle'],
#  ['john.jones', 'riverbend'],
#  ['mary.martinez', 'digitaldawn'],
#  ['david.moore', 'solarflare'],
#  ['mary.smith', 'digitaldawn'],
#  ['john.thomas', 'techsparkle'],
#  ['john.smith', 'digitaldawn'],
#  ['mary.anderson', 'greengrove'],
#  ['jennifer.anderson', 'riverbend'],
#  ['barbara.johnson', 'greengrove'],
#  ['mary.smith', 'techsparkle'],
#  ['joseph.anderson', 'riverbend'],
#  ['barbara.wilson', 'greengrove'],
#  ['joseph.thomas', 'techsparkle'],
#  ['linda.rodriguez', 'digitaldawn'],
#  ['mary.moore', 'riverbend'],
#  ['susan.smith', 'greengrove'],
#  ['robert.davis', 'techsparkle'],
#  ['joseph.garcia', 'solarflare'],
#  ['patricia.rodriguez', 'quantumbridge'],
#  ['linda.brown', 'quantumbridge'],
#  ['jessica.williams', 'greengrove'],
#  ['linda.martinez', 'digitaldawn'],
#  ['thomas.brown', 'digitaldawn'],
#  ['thomas.martinez', 'riverbend'],
#  ['barbara.brown', 'greengrove'],
#  ['john.wilson', 'digitaldawn'],
#  ['james.smith', 'greengrove'],
#  ['james.brown', 'digitaldawn'],
#  ['william.thomas', 'greengrove'],
#  ['michael.rodriguez', 'bluestream'],
#  ['patricia.smith', 'solarflare'],
#  ['susan.williams', 'solarflare'],
#  ['patricia.taylor', 'echovalley'],
#  ['linda.johnson', 'solarflare'],
#  ['michael.wilson', 'greengrove'],
#  ['michael.johnson', 'digitaldawn'],
#  ['patricia.garcia', 'techsparkle'],
#  ['william.rodriguez', 'techsparkle'],
#  ['joseph.miller', 'solarflare'],
#  ['elizabeth.anderson', 'riverbend'],
#  ['jessica.miller', 'techsparkle'],
#  ['william.martinez', 'quantumbridge'],
#  ['william.miller', 'techsparkle'],
#  ['david.martinez', 'echovalley'],
#  ['mary.williams', 'greengrove'],
#  ['mary.johnson', 'quantumbridge'],
#  ['linda.davis', 'greengrove'],
#  ['patricia.martinez', 'bluestream'],
#  ['thomas.rodriguez', 'riverbend'],
#  ['john.jones', 'bluestream'],
#  ['joseph.thomas', 'solarflare'],
#  ['david.smith', 'bluestream'],
#  ['joseph.johnson', 'bluestream'],
#  ['barbara.williams', 'techsparkle'],
#  ['james.moore', 'greengrove'],
#  ['mary.brown', 'riverbend'],
#  ['joseph.johnson', 'digitaldawn'],
#  ['joseph.anderson', 'digitaldawn'],
#  ['linda.thomas', 'digitaldawn'],
#  ['james.johnson', 'quantumbridge'],
#  ['john.anderson', 'greengrove'],
#  ['robert.williams', 'solarflare'],
#  ['david.wilson', 'digitaldawn'],
#  ['thomas.thomas', 'echovalley'],
#  ['john.taylor', 'solarflare'],
#  ['john.garcia', 'bluestream'],
#  ['robert.anderson', 'echovalley'],
#  ['thomas.thomas', 'techsparkle'],
#  ['david.anderson', 'greengrove'],
#  ['jennifer.anderson', 'techsparkle'],
#  ['susan.martinez', 'greengrove'],
#  ['michael.rodriguez', 'greengrove'],
#  ['william.davis', 'riverbend'],
#  ['barbara.jones', 'bluestream'],
#  ['jessica.garcia', 'bluestream'],
#  ['robert.taylor', 'quantumbridge'],
#  ['david.thomas', 'quantumbridge'],
#  ['william.williams', 'quantumbridge'],
#  ['barbara.hernandez', 'solarflare'],
#  ['thomas.jones', 'solarflare'],
#  ['susan.moore', 'quantumbridge'],
#  ['william.rodriguez', 'bluestream'],
#  ['patricia.wilson', 'bluestream'],
#  ['jessica.davis', 'solarflare'],
#  ['thomas.williams', 'greengrove'],
#  ['mary.rodriguez', 'riverbend'],
#  ['james.garcia', 'echovalley'],
#  ['james.garcia', 'techsparkle'],
#  ['david.brown', 'echovalley'],
#  ['jessica.thomas', 'techsparkle'],
#  ['linda.hernandez', 'echovalley'],
#  ['william.garcia', 'greengrove'],
#  ['jessica.anderson', 'bluestream'],
#  ['william.martinez', 'solarflare'],
#  ['john.moore', 'quantumbridge'],
#  ['david.johnson', 'riverbend'],
#  ['elizabeth.williams', 'bluestream'],
#  ['mary.brown', 'techsparkle'],
#  ['james.wilson', 'techsparkle'],
#  ['jessica.wilson', 'greengrove'],
#  ['william.hernandez', 'riverbend'],
#  ['susan.thomas', 'quantumbridge'],
#  ['david.miller', 'echovalley'],
#  ['jessica.wilson', 'riverbend'],
#  ['elizabeth.martinez', 'riverbend'],
#  ['barbara.davis', 'techsparkle'],
#  ['john.jones', 'quantumbridge'],
#  ['susan.jones', 'bluestream'],
#  ['joseph.martinez', 'quantumbridge'],
#  ['john.garcia', 'digitaldawn'],
#  ['william.taylor', 'riverbend'],
#  ['robert.martinez', 'quantumbridge'],
#  ['jennifer.williams', 'techsparkle'],
#  ['joseph.williams', 'techsparkle'],
#  ['patricia.jones', 'greengrove'],
#  ['david.garcia', 'techsparkle'],
#  ['barbara.moore', 'digitaldawn'],
#  ['thomas.williams', 'greengrove'],
#  ['michael.johnson', 'greengrove'],
#  ['linda.wilson', 'quantumbridge'],
#  ['robert.anderson', 'solarflare'],
#  ['robert.jones', 'riverbend'],
#  ['thomas.davis', 'digitaldawn'],
#  ['barbara.williams', 'techsparkle'],
#  ['john.davis', 'greengrove'],
#  ['linda.martinez', 'riverbend'],
#  ['linda.garcia', 'echovalley'],
#  ['elizabeth.johnson', 'bluestream'],
#  ['linda.wilson', 'bluestream'],
#  ['jessica.smith', 'quantumbridge'],
#  ['susan.williams', 'bluestream'],
#  ['barbara.garcia', 'echovalley'],
#  ['joseph.brown', 'echovalley'],
#  ['michael.johnson', 'greengrove'],
#  ['susan.jones', 'digitaldawn'],
#  ['mary.rodriguez', 'echovalley'],
#  ['john.hernandez', 'quantumbridge'],
#  ['susan.moore', 'digitaldawn'],
#  ['michael.johnson', 'techsparkle'],
#  ['john.garcia', 'bluestream'],
#  ['susan.taylor', 'solarflare'],
#  ['mary.thomas', 'bluestream'],
#  ['john.wilson', 'techsparkle'],
#  ['william.taylor', 'riverbend'],
#  ['patricia.jones', 'greengrove'],
#  ['david.anderson', 'riverbend'],
#  ['patricia.williams', 'riverbend'],
#  ['susan.hernandez', 'quantumbridge'],
#  ['jennifer.rodriguez', 'riverbend'],
#  ['jennifer.johnson', 'riverbend'],
#  ['william.rodriguez', 'echovalley'],
#  ['mary.brown', 'greengrove'],
#  ['mary.brown', 'echovalley'],
#  ['thomas.smith', 'quantumbridge'],
#  ['susan.brown', 'techsparkle'],
#  ['linda.taylor', 'bluestream'],
#  ['jennifer.brown', 'techsparkle'],
#  ['susan.williams', 'echovalley'],
#  ['michael.brown', 'quantumbridge'],
#  ['james.martinez', 'bluestream'],
#  ['robert.davis', 'bluestream'],
#  ['william.garcia', 'quantumbridge'],
#  ['michael.thomas', 'quantumbridge'],
#  ['mary.martinez', 'echovalley'],
#  ['jennifer.moore', 'solarflare'],
#  ['john.williams', 'greengrove'],
#  ['robert.smith', 'greengrove'],
#  ['patricia.smith', 'bluestream'],
#  ['patricia.moore', 'solarflare'],
#  ['susan.jones', 'echovalley'],
#  ['elizabeth.miller', 'solarflare'],
#  ['patricia.martinez', 'solarflare'],
#  ['barbara.martinez', 'solarflare'],
#  ['joseph.anderson', 'solarflare'],
#  ['jennifer.thomas', 'techsparkle'],
#  ['james.johnson', 'riverbend'],
#  ['robert.anderson', 'digitaldawn'],
#  ['michael.rodriguez', 'quantumbridge'],
#  ['patricia.smith', 'digitaldawn'],
#  ['robert.williams', 'greengrove'],
#  ['jennifer.jones', 'riverbend'],
#  ['joseph.miller', 'echovalley'],
#  ['barbara.martinez', 'solarflare'],
#  ['barbara.davis', 'echovalley'],
#  ['james.jones', 'techsparkle'],
#  ['robert.johnson', 'bluestream'],
#  ['barbara.thomas', 'riverbend'],
#  ['barbara.williams', 'bluestream'],
#  ['john.martinez', 'riverbend'],
#  ['robert.thomas', 'techsparkle'],
#  ['jessica.brown', 'riverbend'],
#  ['michael.wilson', 'quantumbridge'],
#  ['barbara.jones', 'echovalley'],
#  ['elizabeth.williams', 'riverbend'],
#  ['william.moore', 'bluestream'],
#  ['jessica.wilson', 'riverbend'],
#  ['mary.garcia', 'echovalley'],
#  ['william.brown', 'echovalley'],
#  ['thomas.wilson', 'echovalley'],
#  ['william.williams', 'greengrove'],
#  ['michael.rodriguez', 'greengrove'],
#  ['david.johnson', 'echovalley'],
#  ['michael.taylor', 'techsparkle'],
#  ['robert.hernandez', 'bluestream'],
#  ['william.wilson', 'echovalley'],
#  ['joseph.davis', 'echovalley'],
#  ['mary.brown', 'riverbend'],
#  ['barbara.garcia', 'riverbend'],
#  ['linda.smith', 'riverbend'],
#  ['robert.martinez', 'bluestream'],
#  ['jennifer.taylor', 'techsparkle'],
#  ['jennifer.brown', 'techsparkle'],
#  ['david.hernandez', 'echovalley'],
#  ['barbara.jones', 'techsparkle'],
#  ['mary.johnson', 'techsparkle'],
#  ['thomas.smith', 'bluestream'],
#  ['susan.williams', 'bluestream'],
#  ['patricia.brown', 'quantumbridge'],
#  ['susan.martinez', 'techsparkle'],
#  ['james.miller', 'techsparkle'],
#  ['james.garcia', 'digitaldawn'],
#  ['jennifer.taylor', 'greengrove'],
#  ['linda.rodriguez', 'echovalley'],
#  ['mary.johnson', 'quantumbridge'],
#  ['michael.brown', 'riverbend'],
#  ['william.davis', 'echovalley'],
#  ['michael.davis', 'bluestream'],
#  ['linda.martinez', 'digitaldawn'],
#  ['mary.williams', 'techsparkle'],
#  ['elizabeth.smith', 'digitaldawn'],
#  ['john.williams', 'digitaldawn'],
#  ['susan.taylor', 'riverbend'],
#  ['linda.brown', 'solarflare'],
#  ['robert.davis', 'echovalley'],
#  ['thomas.garcia', 'solarflare'],
#  ['jennifer.moore', 'solarflare'],
#  ['linda.williams', 'techsparkle'],
#  ['jessica.martinez', 'digitaldawn'],
#  ['barbara.martinez', 'greengrove'],
#  ['jennifer.taylor', 'quantumbridge'],
#  ['jessica.garcia', 'solarflare'],
#  ['patricia.jones', 'echovalley'],
#  ['barbara.martinez', 'solarflare'],
#  ['michael.miller', 'quantumbridge'],
#  ['elizabeth.garcia', 'bluestream'],
#  ['patricia.taylor', 'quantumbridge'],
#  ['jennifer.anderson', 'bluestream'],
#  ['thomas.moore', 'digitaldawn'],
#  ['john.anderson', 'echovalley'],
#  ['susan.wilson', 'quantumbridge'],
#  ['david.rodriguez', 'echovalley'],
#  ['jessica.davis', 'quantumbridge'],
#  ['david.wilson', 'quantumbridge'],
#  ['elizabeth.thomas', 'techsparkle'],
#  ['susan.taylor', 'digitaldawn'],
#  ['susan.anderson', 'greengrove'],
#  ['robert.miller', 'echovalley'],
#  ['joseph.wilson', 'digitaldawn'],
#  ['joseph.thomas', 'quantumbridge'],
#  ['robert.wilson', 'bluestream']]

# %% [markdown]
# ## E7.3
# Given the list of emails from the previous exercise, create a table with the following format:
#
# ```
# name = Login               domain = Domain
# name = login1              domain = domain1
# name = login2              domain = domain2
# name = loginn              domain = domainn
# ```

# %%
#emails_format

def pretty_print(info):
    name, domain = info
    spaces = 20 - len(name)
    result = 'name = ' + name + spaces*' ' + 'domain = ' + domain
    return result

# %%
pretty_print(['mary.davis', 'echovalley'])
# Out:
# 'name = mary.davis          domain = echovalley'

# %%
for user in emails_format:
    print(
        pretty_print(user)
    )
# Out:
# name = jessica.thomas      domain = quantumbridge
# name = thomas.martinez     domain = solarflare
# name = mary.miller         domain = quantumbridge
# name = robert.jones        domain = techsparkle
# name = elizabeth.martinez  domain = digitaldawn
# name = robert.anderson     domain = greengrove
# name = william.smith       domain = digitaldawn
# name = thomas.davis        domain = digitaldawn
# name = linda.wilson        domain = quantumbridge
# name = mary.williams       domain = bluestream
# name = susan.davis         domain = greengrove
# name = robert.miller       domain = riverbend
# name = david.miller        domain = riverbend
# name = patricia.rodriguez  domain = echovalley
# name = patricia.johnson    domain = digitaldawn
# name = patricia.martinez   domain = bluestream
# name = mary.davis          domain = echovalley
# name = linda.miller        domain = riverbend
# name = john.martinez       domain = solarflare
# name = mary.thomas         domain = techsparkle
# name = mary.wilson         domain = riverbend
# name = robert.wilson       domain = greengrove
# name = thomas.jones        domain = quantumbridge
# name = linda.smith         domain = bluestream
# name = jessica.moore       domain = bluestream
# name = elizabeth.thomas    domain = bluestream
# name = thomas.thomas       domain = digitaldawn
# name = jennifer.brown      domain = bluestream
# name = michael.moore       domain = bluestream
# name = john.thomas         domain = techsparkle
# name = john.davis          domain = echovalley
# name = robert.johnson      domain = echovalley
# name = elizabeth.moore     domain = greengrove
# name = susan.wilson        domain = bluestream
# name = jessica.johnson     domain = techsparkle
# name = jennifer.anderson   domain = techsparkle
# name = jennifer.smith      domain = digitaldawn
# name = thomas.anderson     domain = echovalley
# name = susan.brown         domain = riverbend
# name = thomas.brown        domain = echovalley
# name = barbara.johnson     domain = quantumbridge
# name = jessica.martinez    domain = techsparkle
# name = susan.hernandez     domain = greengrove
# name = jennifer.thomas     domain = greengrove
# name = jessica.wilson      domain = riverbend
# name = robert.moore        domain = riverbend
# name = linda.miller        domain = bluestream
# name = linda.garcia        domain = techsparkle
# name = elizabeth.thomas    domain = digitaldawn
# name = susan.davis         domain = riverbend
# name = patricia.williams   domain = quantumbridge
# name = james.garcia        domain = solarflare
# name = john.anderson       domain = greengrove
# name = thomas.taylor       domain = greengrove
# name = patricia.wilson     domain = digitaldawn
# name = mary.miller         domain = quantumbridge
# name = linda.thomas        domain = riverbend
# name = michael.davis       domain = techsparkle
# name = john.moore          domain = bluestream
# name = michael.rodriguez   domain = bluestream
# name = susan.anderson      domain = techsparkle
# name = john.johnson        domain = digitaldawn
# name = michael.thomas      domain = echovalley
# name = thomas.brown        domain = solarflare
# name = david.johnson       domain = echovalley
# name = linda.davis         domain = solarflare
# name = patricia.garcia     domain = riverbend
# name = robert.rodriguez    domain = bluestream
# name = david.davis         domain = digitaldawn
# name = elizabeth.wilson    domain = echovalley
# name = william.anderson    domain = digitaldawn
# name = mary.davis          domain = techsparkle
# name = james.miller        domain = bluestream
# name = william.jones       domain = greengrove
# name = thomas.garcia       domain = riverbend
# name = robert.brown        domain = quantumbridge
# name = thomas.williams     domain = riverbend
# name = elizabeth.garcia    domain = bluestream
# name = james.jones         domain = echovalley
# name = jennifer.taylor     domain = greengrove
# name = robert.brown        domain = riverbend
# name = barbara.smith       domain = quantumbridge
# name = john.miller         domain = quantumbridge
# name = david.thomas        domain = quantumbridge
# name = thomas.moore        domain = riverbend
# name = linda.anderson      domain = digitaldawn
# name = patricia.martinez   domain = greengrove
# name = william.taylor      domain = echovalley
# name = robert.smith        domain = echovalley
# name = james.johnson       domain = riverbend
# name = mary.thomas         domain = bluestream
# name = michael.taylor      domain = solarflare
# name = joseph.davis        domain = quantumbridge
# name = susan.miller        domain = echovalley
# name = linda.williams      domain = echovalley
# name = jessica.martinez    domain = digitaldawn
# name = mary.jones          domain = greengrove
# name = linda.miller        domain = greengrove
# name = jennifer.rodriguez  domain = solarflare
# name = mary.garcia         domain = quantumbridge
# name = robert.wilson       domain = echovalley
# name = john.rodriguez      domain = bluestream
# name = robert.rodriguez    domain = bluestream
# name = william.garcia      domain = bluestream
# name = barbara.thomas      domain = techsparkle
# name = thomas.brown        domain = greengrove
# name = david.rodriguez     domain = riverbend
# name = thomas.anderson     domain = echovalley
# name = james.brown         domain = bluestream
# name = elizabeth.hernandez domain = quantumbridge
# name = jennifer.williams   domain = quantumbridge
# name = robert.miller       domain = solarflare
# name = susan.moore         domain = solarflare
# name = thomas.martinez     domain = echovalley
# name = michael.williams    domain = techsparkle
# name = jennifer.thomas     domain = digitaldawn
# name = patricia.rodriguez  domain = techsparkle
# name = jennifer.smith      domain = quantumbridge
# name = jennifer.martinez   domain = digitaldawn
# name = mary.garcia         domain = quantumbridge
# name = mary.miller         domain = solarflare
# name = jennifer.garcia     domain = greengrove
# name = david.thomas        domain = solarflare
# name = patricia.hernandez  domain = digitaldawn
# name = thomas.martinez     domain = solarflare
# name = joseph.smith        domain = echovalley
# name = robert.wilson       domain = digitaldawn
# name = barbara.williams    domain = echovalley
# name = william.brown       domain = greengrove
# name = linda.smith         domain = riverbend
# name = jennifer.brown      domain = bluestream
# name = jennifer.taylor     domain = greengrove
# name = patricia.moore      domain = solarflare
# name = patricia.garcia     domain = bluestream
# name = mary.jones          domain = greengrove
# name = michael.garcia      domain = solarflare
# name = barbara.brown       domain = solarflare
# name = joseph.wilson       domain = solarflare
# name = john.garcia         domain = solarflare
# name = mary.rodriguez      domain = riverbend
# name = james.johnson       domain = riverbend
# name = thomas.martinez     domain = digitaldawn
# name = john.anderson       domain = greengrove
# name = joseph.brown        domain = digitaldawn
# name = william.moore       domain = greengrove
# name = mary.smith          domain = digitaldawn
# name = elizabeth.garcia    domain = riverbend
# name = susan.garcia        domain = digitaldawn
# name = robert.miller       domain = solarflare
# name = robert.johnson      domain = echovalley
# name = susan.smith         domain = echovalley
# name = john.williams       domain = techsparkle
# name = william.brown       domain = quantumbridge
# name = robert.rodriguez    domain = quantumbridge
# name = jennifer.thomas     domain = echovalley
# name = barbara.taylor      domain = echovalley
# name = robert.rodriguez    domain = digitaldawn
# name = michael.anderson    domain = bluestream
# name = mary.brown          domain = digitaldawn
# name = robert.williams     domain = quantumbridge
# name = patricia.martinez   domain = riverbend
# name = michael.rodriguez   domain = echovalley
# name = barbara.hernandez   domain = digitaldawn
# name = thomas.thomas       domain = digitaldawn
# name = jessica.hernandez   domain = techsparkle
# name = david.taylor        domain = solarflare
# name = james.moore         domain = techsparkle
# name = jessica.taylor      domain = digitaldawn
# name = joseph.wilson       domain = echovalley
# name = john.thomas         domain = digitaldawn
# name = robert.hernandez    domain = digitaldawn
# name = michael.johnson     domain = techsparkle
# name = mary.taylor         domain = solarflare
# name = elizabeth.miller    domain = greengrove
# name = patricia.davis      domain = quantumbridge
# name = patricia.thomas     domain = greengrove
# name = david.martinez      domain = greengrove
# name = robert.brown        domain = riverbend
# name = thomas.brown        domain = riverbend
# name = elizabeth.hernandez domain = riverbend
# name = jennifer.taylor     domain = techsparkle
# name = barbara.moore       domain = bluestream
# name = jessica.garcia      domain = quantumbridge
# name = robert.anderson     domain = solarflare
# name = susan.brown         domain = echovalley
# name = robert.johnson      domain = riverbend
# name = jennifer.hernandez  domain = techsparkle
# name = barbara.johnson     domain = quantumbridge
# name = jessica.davis       domain = greengrove
# name = joseph.taylor       domain = techsparkle
# name = william.smith       domain = riverbend
# name = joseph.thomas       domain = quantumbridge
# name = thomas.wilson       domain = solarflare
# name = william.thomas      domain = solarflare
# name = john.hernandez      domain = solarflare
# name = michael.martinez    domain = bluestream
# name = patricia.anderson   domain = greengrove
# name = michael.garcia      domain = greengrove
# name = susan.davis         domain = greengrove
# name = elizabeth.anderson  domain = echovalley
# name = elizabeth.garcia    domain = echovalley
# name = michael.garcia      domain = riverbend
# name = barbara.miller      domain = echovalley
# name = robert.moore        domain = echovalley
# name = michael.davis       domain = greengrove
# name = jennifer.taylor     domain = quantumbridge
# name = jennifer.smith      domain = quantumbridge
# name = joseph.smith        domain = quantumbridge
# name = david.taylor        domain = digitaldawn
# name = john.garcia         domain = quantumbridge
# name = william.davis       domain = greengrove
# name = james.johnson       domain = techsparkle
# name = barbara.anderson    domain = bluestream
# name = linda.smith         domain = digitaldawn
# name = patricia.thomas     domain = quantumbridge
# name = david.anderson      domain = riverbend
# name = john.taylor         domain = digitaldawn
# name = john.brown          domain = solarflare
# name = jennifer.miller     domain = solarflare
# name = elizabeth.anderson  domain = bluestream
# name = john.smith          domain = techsparkle
# name = susan.thomas        domain = greengrove
# name = john.johnson        domain = quantumbridge
# name = patricia.davis      domain = techsparkle
# name = jessica.anderson    domain = techsparkle
# name = elizabeth.rodriguez domain = solarflare
# name = joseph.moore        domain = solarflare
# name = susan.davis         domain = greengrove
# name = thomas.smith        domain = riverbend
# name = mary.thomas         domain = quantumbridge
# name = patricia.moore      domain = quantumbridge
# name = jennifer.hernandez  domain = solarflare
# name = john.davis          domain = quantumbridge
# name = patricia.davis      domain = greengrove
# name = patricia.hernandez  domain = riverbend
# name = david.williams      domain = solarflare
# name = michael.martinez    domain = greengrove
# name = james.anderson      domain = riverbend
# name = james.johnson       domain = bluestream
# name = elizabeth.moore     domain = bluestream
# name = robert.taylor       domain = quantumbridge
# name = barbara.thomas      domain = digitaldawn
# name = jessica.smith       domain = solarflare
# name = mary.miller         domain = digitaldawn
# name = robert.hernandez    domain = solarflare
# name = susan.brown         domain = digitaldawn
# name = jessica.wilson      domain = riverbend
# name = david.thomas        domain = greengrove
# name = barbara.taylor      domain = riverbend
# name = mary.davis          domain = greengrove
# name = joseph.miller       domain = riverbend
# name = jessica.taylor      domain = techsparkle
# name = john.martinez       domain = riverbend
# name = john.moore          domain = bluestream
# name = thomas.williams     domain = bluestream
# name = jessica.thomas      domain = echovalley
# name = john.brown          domain = quantumbridge
# name = barbara.martinez    domain = echovalley
# name = james.brown         domain = quantumbridge
# name = linda.wilson        domain = solarflare
# name = jennifer.hernandez  domain = digitaldawn
# name = barbara.jones       domain = solarflare
# name = mary.moore          domain = echovalley
# name = william.davis       domain = greengrove
# name = david.brown         domain = digitaldawn
# name = john.rodriguez      domain = echovalley
# name = david.smith         domain = digitaldawn
# name = michael.davis       domain = bluestream
# name = john.johnson        domain = techsparkle
# name = barbara.martinez    domain = digitaldawn
# name = robert.hernandez    domain = riverbend
# name = jennifer.martinez   domain = techsparkle
# name = mary.moore          domain = bluestream
# name = joseph.johnson      domain = digitaldawn
# name = jennifer.rodriguez  domain = digitaldawn
# name = john.anderson       domain = digitaldawn
# name = thomas.anderson     domain = solarflare
# name = michael.davis       domain = solarflare
# name = elizabeth.hernandez domain = quantumbridge
# name = william.davis       domain = quantumbridge
# name = patricia.smith      domain = greengrove
# name = thomas.smith        domain = riverbend
# name = john.wilson         domain = greengrove
# name = robert.thomas       domain = greengrove
# name = william.jones       domain = bluestream
# name = michael.brown       domain = quantumbridge
# name = jennifer.rodriguez  domain = digitaldawn
# name = susan.smith         domain = digitaldawn
# name = jessica.jones       domain = echovalley
# name = barbara.wilson      domain = greengrove
# name = barbara.miller      domain = solarflare
# name = susan.garcia        domain = techsparkle
# name = patricia.taylor     domain = techsparkle
# name = jessica.anderson    domain = riverbend
# name = jennifer.garcia     domain = greengrove
# name = patricia.anderson   domain = riverbend
# name = barbara.thomas      domain = bluestream
# name = jessica.smith       domain = quantumbridge
# name = michael.johnson     domain = echovalley
# name = patricia.johnson    domain = solarflare
# name = michael.williams    domain = solarflare
# name = john.brown          domain = solarflare
# name = joseph.taylor       domain = greengrove
# name = thomas.garcia       domain = riverbend
# name = susan.davis         domain = echovalley
# name = david.wilson        domain = techsparkle
# name = thomas.rodriguez    domain = greengrove
# name = david.anderson      domain = digitaldawn
# name = robert.moore        domain = quantumbridge
# name = barbara.moore       domain = greengrove
# name = patricia.johnson    domain = greengrove
# name = patricia.wilson     domain = echovalley
# name = joseph.miller       domain = greengrove
# name = thomas.smith        domain = techsparkle
# name = mary.garcia         domain = greengrove
# name = william.brown       domain = quantumbridge
# name = jessica.anderson    domain = greengrove
# name = linda.taylor        domain = digitaldawn
# name = linda.martinez      domain = greengrove
# name = john.williams       domain = riverbend
# name = james.moore         domain = echovalley
# name = robert.wilson       domain = quantumbridge
# name = robert.garcia       domain = echovalley
# name = jessica.martinez    domain = techsparkle
# name = jennifer.moore      domain = riverbend
# name = mary.davis          domain = echovalley
# name = mary.johnson        domain = techsparkle
# name = david.moore         domain = digitaldawn
# name = elizabeth.jones     domain = quantumbridge
# name = david.jones         domain = echovalley
# name = susan.moore         domain = digitaldawn
# name = barbara.taylor      domain = bluestream
# name = james.jones         domain = greengrove
# name = robert.moore        domain = quantumbridge
# name = jessica.smith       domain = solarflare
# name = elizabeth.wilson    domain = echovalley
# name = john.taylor         domain = solarflare
# name = david.rodriguez     domain = greengrove
# name = thomas.davis        domain = greengrove
# name = jennifer.rodriguez  domain = digitaldawn
# name = david.miller        domain = riverbend
# name = michael.smith       domain = quantumbridge
# name = susan.hernandez     domain = techsparkle
# name = james.johnson       domain = riverbend
# name = james.thomas        domain = techsparkle
# name = joseph.anderson     domain = greengrove
# name = joseph.hernandez    domain = solarflare
# name = patricia.wilson     domain = greengrove
# name = david.miller        domain = bluestream
# name = david.williams      domain = quantumbridge
# name = william.johnson     domain = greengrove
# name = susan.jones         domain = techsparkle
# name = david.moore         domain = greengrove
# name = patricia.martinez   domain = bluestream
# name = james.thomas        domain = solarflare
# name = linda.martinez      domain = riverbend
# name = david.rodriguez     domain = echovalley
# name = joseph.brown        domain = riverbend
# name = james.wilson        domain = techsparkle
# name = patricia.wilson     domain = echovalley
# name = james.moore         domain = echovalley
# name = jessica.davis       domain = digitaldawn
# name = john.moore          domain = bluestream
# name = david.anderson      domain = solarflare
# name = james.moore         domain = quantumbridge
# name = michael.moore       domain = riverbend
# name = michael.moore       domain = echovalley
# name = john.smith          domain = quantumbridge
# name = michael.jones       domain = greengrove
# name = david.williams      domain = bluestream
# name = joseph.taylor       domain = echovalley
# name = william.garcia      domain = digitaldawn
# name = elizabeth.brown     domain = techsparkle
# name = elizabeth.miller    domain = bluestream
# name = barbara.wilson      domain = techsparkle
# name = david.jones         domain = techsparkle
# name = william.martinez    domain = techsparkle
# name = david.garcia        domain = echovalley
# name = jessica.martinez    domain = riverbend
# name = jessica.brown       domain = greengrove
# name = thomas.thomas       domain = quantumbridge
# name = thomas.martinez     domain = bluestream
# name = jennifer.davis      domain = greengrove
# name = jennifer.wilson     domain = digitaldawn
# name = jennifer.taylor     domain = riverbend
# name = jennifer.anderson   domain = quantumbridge
# name = jennifer.garcia     domain = greengrove
# name = james.anderson      domain = quantumbridge
# name = mary.rodriguez      domain = solarflare
# name = patricia.martinez   domain = digitaldawn
# name = william.williams    domain = digitaldawn
# name = susan.taylor        domain = solarflare
# name = mary.smith          domain = echovalley
# name = barbara.thomas      domain = digitaldawn
# name = jessica.taylor      domain = digitaldawn
# name = william.thomas      domain = solarflare
# name = william.moore       domain = riverbend
# name = barbara.rodriguez   domain = digitaldawn
# name = jennifer.brown      domain = bluestream
# name = david.johnson       domain = techsparkle
# name = jennifer.jones      domain = solarflare
# name = robert.wilson       domain = greengrove
# name = mary.smith          domain = echovalley
# name = susan.taylor        domain = digitaldawn
# name = thomas.hernandez    domain = greengrove
# name = jessica.williams    domain = greengrove
# name = patricia.anderson   domain = techsparkle
# name = james.williams      domain = bluestream
# name = jessica.thomas      domain = riverbend
# name = jessica.moore       domain = bluestream
# name = james.johnson       domain = greengrove
# name = jessica.moore       domain = digitaldawn
# name = elizabeth.thomas    domain = riverbend
# name = joseph.anderson     domain = bluestream
# name = william.martinez    domain = bluestream
# name = thomas.martinez     domain = echovalley
# name = linda.miller        domain = digitaldawn
# name = linda.brown         domain = quantumbridge
# name = mary.rodriguez      domain = echovalley
# name = robert.williams     domain = echovalley
# name = michael.jones       domain = echovalley
# name = jessica.martinez    domain = bluestream
# name = jessica.wilson      domain = quantumbridge
# name = mary.jones          domain = bluestream
# name = robert.johnson      domain = greengrove
# name = robert.martinez     domain = quantumbridge
# name = jessica.garcia      domain = riverbend
# name = john.rodriguez      domain = echovalley
# name = robert.rodriguez    domain = riverbend
# name = robert.miller       domain = solarflare
# name = robert.miller       domain = echovalley
# name = robert.johnson      domain = solarflare
# name = linda.johnson       domain = bluestream
# name = mary.moore          domain = echovalley
# name = patricia.smith      domain = solarflare
# name = joseph.jones        domain = greengrove
# name = james.rodriguez     domain = solarflare
# name = john.johnson        domain = greengrove
# name = linda.johnson       domain = quantumbridge
# name = patricia.smith      domain = greengrove
# name = michael.anderson    domain = echovalley
# name = elizabeth.garcia    domain = digitaldawn
# name = mary.davis          domain = bluestream
# name = patricia.miller     domain = techsparkle
# name = michael.wilson      domain = riverbend
# name = susan.taylor        domain = solarflare
# name = patricia.moore      domain = digitaldawn
# name = mary.taylor         domain = bluestream
# name = david.martinez      domain = techsparkle
# name = mary.miller         domain = greengrove
# name = william.martinez    domain = quantumbridge
# name = susan.taylor        domain = quantumbridge
# name = linda.anderson      domain = quantumbridge
# name = william.martinez    domain = quantumbridge
# name = mary.brown          domain = greengrove
# name = john.williams       domain = riverbend
# name = susan.moore         domain = digitaldawn
# name = joseph.johnson      domain = riverbend
# name = robert.garcia       domain = quantumbridge
# name = linda.johnson       domain = greengrove
# name = barbara.smith       domain = greengrove
# name = jennifer.davis      domain = bluestream
# name = susan.taylor        domain = echovalley
# name = jennifer.miller     domain = greengrove
# name = james.moore         domain = techsparkle
# name = joseph.thomas       domain = techsparkle
# name = susan.rodriguez     domain = echovalley
# name = jessica.jones       domain = bluestream
# name = james.brown         domain = greengrove
# name = joseph.martinez     domain = riverbend
# name = joseph.taylor       domain = bluestream
# name = susan.anderson      domain = techsparkle
# name = jennifer.taylor     domain = bluestream
# name = william.taylor      domain = echovalley
# name = barbara.jones       domain = bluestream
# name = robert.williams     domain = greengrove
# name = patricia.anderson   domain = greengrove
# name = linda.smith         domain = quantumbridge
# name = david.johnson       domain = digitaldawn
# name = david.jones         domain = bluestream
# name = robert.taylor       domain = echovalley
# name = john.hernandez      domain = quantumbridge
# name = patricia.davis      domain = riverbend
# name = elizabeth.rodriguez domain = digitaldawn
# name = jennifer.hernandez  domain = bluestream
# name = patricia.martinez   domain = echovalley
# name = linda.smith         domain = techsparkle
# name = robert.smith        domain = echovalley
# name = michael.jones       domain = quantumbridge
# name = thomas.williams     domain = greengrove
# name = jessica.thomas      domain = quantumbridge
# name = linda.anderson      domain = greengrove
# name = elizabeth.williams  domain = echovalley
# name = joseph.garcia       domain = greengrove
# name = jessica.wilson      domain = digitaldawn
# name = joseph.anderson     domain = riverbend
# name = michael.hernandez   domain = quantumbridge
# name = william.wilson      domain = bluestream
# name = jennifer.martinez   domain = techsparkle
# name = james.martinez      domain = techsparkle
# name = david.taylor        domain = quantumbridge
# name = joseph.williams     domain = quantumbridge
# name = jessica.williams    domain = echovalley
# name = jessica.davis       domain = greengrove
# name = michael.moore       domain = riverbend
# name = william.miller      domain = quantumbridge
# name = john.davis          domain = echovalley
# name = jennifer.taylor     domain = riverbend
# name = james.johnson       domain = digitaldawn
# name = james.hernandez     domain = greengrove
# name = jessica.thomas      domain = solarflare
# name = david.thomas        domain = techsparkle
# name = michael.moore       domain = greengrove
# name = david.garcia        domain = echovalley
# name = john.davis          domain = quantumbridge
# name = william.jones       domain = bluestream
# name = robert.thomas       domain = greengrove
# name = joseph.taylor       domain = digitaldawn
# name = linda.wilson        domain = bluestream
# name = patricia.garcia     domain = solarflare
# name = michael.johnson     domain = echovalley
# name = william.rodriguez   domain = greengrove
# name = jennifer.wilson     domain = greengrove
# name = joseph.jones        domain = techsparkle
# name = linda.rodriguez     domain = digitaldawn
# name = linda.williams      domain = riverbend
# name = elizabeth.wilson    domain = quantumbridge
# name = joseph.brown        domain = echovalley
# name = david.davis         domain = digitaldawn
# name = linda.johnson       domain = digitaldawn
# name = john.johnson        domain = echovalley
# name = jennifer.hernandez  domain = echovalley
# name = james.taylor        domain = riverbend
# name = elizabeth.jones     domain = solarflare
# name = joseph.rodriguez    domain = digitaldawn
# name = william.taylor      domain = greengrove
# name = thomas.anderson     domain = quantumbridge
# name = patricia.moore      domain = greengrove
# name = mary.thomas         domain = greengrove
# name = barbara.moore       domain = techsparkle
# name = barbara.jones       domain = solarflare
# name = william.smith       domain = greengrove
# name = jessica.garcia      domain = techsparkle
# name = william.garcia      domain = quantumbridge
# name = james.thomas        domain = riverbend
# name = susan.hernandez     domain = echovalley
# name = jennifer.jones      domain = techsparkle
# name = linda.wilson        domain = solarflare
# name = patricia.brown      domain = riverbend
# name = thomas.garcia       domain = digitaldawn
# name = elizabeth.moore     domain = bluestream
# name = elizabeth.smith     domain = bluestream
# name = robert.williams     domain = bluestream
# name = john.johnson        domain = techsparkle
# name = michael.brown       domain = greengrove
# name = robert.taylor       domain = greengrove
# name = susan.miller        domain = digitaldawn
# name = james.miller        domain = digitaldawn
# name = thomas.rodriguez    domain = quantumbridge
# name = david.johnson       domain = solarflare
# name = patricia.martinez   domain = techsparkle
# name = john.miller         domain = echovalley
# name = david.taylor        domain = riverbend
# name = barbara.hernandez   domain = greengrove
# name = thomas.hernandez    domain = riverbend
# name = james.martinez      domain = bluestream
# name = linda.rodriguez     domain = bluestream
# name = barbara.jones       domain = quantumbridge
# name = david.johnson       domain = echovalley
# name = linda.smith         domain = riverbend
# name = elizabeth.hernandez domain = greengrove
# name = robert.hernandez    domain = bluestream
# name = susan.smith         domain = quantumbridge
# name = thomas.garcia       domain = echovalley
# name = michael.rodriguez   domain = techsparkle
# name = susan.brown         domain = bluestream
# name = james.martinez      domain = digitaldawn
# name = jennifer.taylor     domain = bluestream
# name = susan.rodriguez     domain = bluestream
# name = joseph.anderson     domain = echovalley
# name = james.moore         domain = bluestream
# name = jessica.moore       domain = riverbend
# name = patricia.moore      domain = digitaldawn
# name = michael.garcia      domain = greengrove
# name = linda.anderson      domain = digitaldawn
# name = robert.moore        domain = techsparkle
# name = william.hernandez   domain = riverbend
# name = james.wilson        domain = solarflare
# name = william.taylor      domain = greengrove
# name = elizabeth.williams  domain = bluestream
# name = jessica.brown       domain = solarflare
# name = david.jones         domain = echovalley
# name = robert.rodriguez    domain = bluestream
# name = jennifer.johnson    domain = quantumbridge
# name = elizabeth.martinez  domain = digitaldawn
# name = patricia.miller     domain = riverbend
# name = linda.smith         domain = greengrove
# name = james.davis         domain = riverbend
# name = david.anderson      domain = greengrove
# name = robert.johnson      domain = techsparkle
# name = robert.anderson     domain = bluestream
# name = thomas.jones        domain = echovalley
# name = james.anderson      domain = echovalley
# name = john.thomas         domain = solarflare
# name = robert.hernandez    domain = echovalley
# name = thomas.miller       domain = quantumbridge
# name = david.miller        domain = greengrove
# name = john.martinez       domain = bluestream
# name = jessica.martinez    domain = echovalley
# name = patricia.wilson     domain = quantumbridge
# name = barbara.davis       domain = greengrove
# name = thomas.smith        domain = solarflare
# name = jessica.smith       domain = riverbend
# name = barbara.garcia      domain = bluestream
# name = michael.thomas      domain = echovalley
# name = john.rodriguez      domain = techsparkle
# name = james.thomas        domain = riverbend
# name = susan.thomas        domain = quantumbridge
# name = linda.williams      domain = echovalley
# name = mary.smith          domain = solarflare
# name = jennifer.brown      domain = greengrove
# name = elizabeth.jones     domain = quantumbridge
# name = barbara.miller      domain = solarflare
# name = barbara.johnson     domain = echovalley
# name = david.brown         domain = solarflare
# name = jessica.jones       domain = quantumbridge
# name = linda.anderson      domain = digitaldawn
# name = michael.wilson      domain = echovalley
# name = david.taylor        domain = riverbend
# name = william.miller      domain = bluestream
# name = elizabeth.hernandez domain = quantumbridge
# name = susan.hernandez     domain = techsparkle
# name = michael.moore       domain = riverbend
# name = william.jones       domain = echovalley
# name = jessica.garcia      domain = greengrove
# name = william.wilson      domain = greengrove
# name = david.garcia        domain = techsparkle
# name = john.miller         domain = echovalley
# name = david.davis         domain = solarflare
# name = barbara.moore       domain = quantumbridge
# name = michael.miller      domain = digitaldawn
# name = mary.brown          domain = quantumbridge
# name = joseph.rodriguez    domain = quantumbridge
# name = jessica.johnson     domain = greengrove
# name = jennifer.davis      domain = techsparkle
# name = michael.jones       domain = quantumbridge
# name = jennifer.moore      domain = greengrove
# name = jessica.hernandez   domain = solarflare
# name = barbara.garcia      domain = echovalley
# name = michael.johnson     domain = bluestream
# name = william.williams    domain = riverbend
# name = mary.davis          domain = quantumbridge
# name = david.jones         domain = bluestream
# name = jessica.taylor      domain = digitaldawn
# name = thomas.thomas       domain = techsparkle
# name = thomas.taylor       domain = greengrove
# name = joseph.davis        domain = bluestream
# name = patricia.taylor     domain = digitaldawn
# name = john.taylor         domain = riverbend
# name = thomas.davis        domain = techsparkle
# name = james.thomas        domain = riverbend
# name = elizabeth.garcia    domain = echovalley
# name = elizabeth.thomas    domain = quantumbridge
# name = james.williams      domain = solarflare
# name = john.thomas         domain = digitaldawn
# name = mary.jones          domain = solarflare
# name = robert.martinez     domain = digitaldawn
# name = john.jones          domain = echovalley
# name = john.johnson        domain = solarflare
# name = jennifer.hernandez  domain = solarflare
# name = john.moore          domain = bluestream
# name = mary.martinez       domain = quantumbridge
# name = thomas.martinez     domain = greengrove
# name = william.garcia      domain = solarflare
# name = thomas.hernandez    domain = greengrove
# name = john.martinez       domain = greengrove
# name = james.moore         domain = techsparkle
# name = david.martinez      domain = solarflare
# name = david.smith         domain = riverbend
# name = john.anderson       domain = bluestream
# name = william.brown       domain = riverbend
# name = james.martinez      domain = digitaldawn
# name = james.williams      domain = greengrove
# name = thomas.brown        domain = echovalley
# name = william.jones       domain = riverbend
# name = elizabeth.rodriguez domain = quantumbridge
# name = james.martinez      domain = solarflare
# name = william.davis       domain = bluestream
# name = linda.brown         domain = digitaldawn
# name = jessica.wilson      domain = digitaldawn
# name = jennifer.moore      domain = riverbend
# name = david.thomas        domain = echovalley
# name = thomas.wilson       domain = solarflare
# name = linda.wilson        domain = echovalley
# name = robert.moore        domain = quantumbridge
# name = thomas.martinez     domain = bluestream
# name = linda.miller        domain = techsparkle
# name = william.smith       domain = echovalley
# name = david.williams      domain = echovalley
# name = joseph.miller       domain = solarflare
# name = william.moore       domain = quantumbridge
# name = mary.hernandez      domain = bluestream
# name = joseph.williams     domain = quantumbridge
# name = john.davis          domain = techsparkle
# name = joseph.moore        domain = bluestream
# name = jessica.taylor      domain = riverbend
# name = mary.smith          domain = digitaldawn
# name = john.davis          domain = solarflare
# name = joseph.hernandez    domain = solarflare
# name = patricia.moore      domain = greengrove
# name = elizabeth.miller    domain = solarflare
# name = joseph.johnson      domain = quantumbridge
# name = joseph.anderson     domain = bluestream
# name = thomas.taylor       domain = quantumbridge
# name = barbara.davis       domain = solarflare
# name = michael.brown       domain = solarflare
# name = elizabeth.rodriguez domain = quantumbridge
# name = thomas.williams     domain = bluestream
# name = thomas.moore        domain = digitaldawn
# name = barbara.williams    domain = greengrove
# name = linda.johnson       domain = echovalley
# name = john.wilson         domain = bluestream
# name = linda.garcia        domain = techsparkle
# name = jennifer.davis      domain = riverbend
# name = patricia.miller     domain = bluestream
# name = elizabeth.hernandez domain = solarflare
# name = elizabeth.garcia    domain = greengrove
# name = james.rodriguez     domain = riverbend
# name = linda.hernandez     domain = digitaldawn
# name = jennifer.smith      domain = greengrove
# name = john.martinez       domain = echovalley
# name = michael.miller      domain = quantumbridge
# name = elizabeth.moore     domain = solarflare
# name = linda.johnson       domain = riverbend
# name = mary.jones          domain = riverbend
# name = joseph.smith        domain = digitaldawn
# name = barbara.taylor      domain = riverbend
# name = david.garcia        domain = riverbend
# name = thomas.davis        domain = bluestream
# name = james.taylor        domain = techsparkle
# name = john.jones          domain = riverbend
# name = mary.martinez       domain = digitaldawn
# name = david.moore         domain = solarflare
# name = mary.smith          domain = digitaldawn
# name = john.thomas         domain = techsparkle
# name = john.smith          domain = digitaldawn
# name = mary.anderson       domain = greengrove
# name = jennifer.anderson   domain = riverbend
# name = barbara.johnson     domain = greengrove
# name = mary.smith          domain = techsparkle
# name = joseph.anderson     domain = riverbend
# name = barbara.wilson      domain = greengrove
# name = joseph.thomas       domain = techsparkle
# name = linda.rodriguez     domain = digitaldawn
# name = mary.moore          domain = riverbend
# name = susan.smith         domain = greengrove
# name = robert.davis        domain = techsparkle
# name = joseph.garcia       domain = solarflare
# name = patricia.rodriguez  domain = quantumbridge
# name = linda.brown         domain = quantumbridge
# name = jessica.williams    domain = greengrove
# name = linda.martinez      domain = digitaldawn
# name = thomas.brown        domain = digitaldawn
# name = thomas.martinez     domain = riverbend
# name = barbara.brown       domain = greengrove
# name = john.wilson         domain = digitaldawn
# name = james.smith         domain = greengrove
# name = james.brown         domain = digitaldawn
# name = william.thomas      domain = greengrove
# name = michael.rodriguez   domain = bluestream
# name = patricia.smith      domain = solarflare
# name = susan.williams      domain = solarflare
# name = patricia.taylor     domain = echovalley
# name = linda.johnson       domain = solarflare
# name = michael.wilson      domain = greengrove
# name = michael.johnson     domain = digitaldawn
# name = patricia.garcia     domain = techsparkle
# name = william.rodriguez   domain = techsparkle
# name = joseph.miller       domain = solarflare
# name = elizabeth.anderson  domain = riverbend
# name = jessica.miller      domain = techsparkle
# name = william.martinez    domain = quantumbridge
# name = william.miller      domain = techsparkle
# name = david.martinez      domain = echovalley
# name = mary.williams       domain = greengrove
# name = mary.johnson        domain = quantumbridge
# name = linda.davis         domain = greengrove
# name = patricia.martinez   domain = bluestream
# name = thomas.rodriguez    domain = riverbend
# name = john.jones          domain = bluestream
# name = joseph.thomas       domain = solarflare
# name = david.smith         domain = bluestream
# name = joseph.johnson      domain = bluestream
# name = barbara.williams    domain = techsparkle
# name = james.moore         domain = greengrove
# name = mary.brown          domain = riverbend
# name = joseph.johnson      domain = digitaldawn
# name = joseph.anderson     domain = digitaldawn
# name = linda.thomas        domain = digitaldawn
# name = james.johnson       domain = quantumbridge
# name = john.anderson       domain = greengrove
# name = robert.williams     domain = solarflare
# name = david.wilson        domain = digitaldawn
# name = thomas.thomas       domain = echovalley
# name = john.taylor         domain = solarflare
# name = john.garcia         domain = bluestream
# name = robert.anderson     domain = echovalley
# name = thomas.thomas       domain = techsparkle
# name = david.anderson      domain = greengrove
# name = jennifer.anderson   domain = techsparkle
# name = susan.martinez      domain = greengrove
# name = michael.rodriguez   domain = greengrove
# name = william.davis       domain = riverbend
# name = barbara.jones       domain = bluestream
# name = jessica.garcia      domain = bluestream
# name = robert.taylor       domain = quantumbridge
# name = david.thomas        domain = quantumbridge
# name = william.williams    domain = quantumbridge
# name = barbara.hernandez   domain = solarflare
# name = thomas.jones        domain = solarflare
# name = susan.moore         domain = quantumbridge
# name = william.rodriguez   domain = bluestream
# name = patricia.wilson     domain = bluestream
# name = jessica.davis       domain = solarflare
# name = thomas.williams     domain = greengrove
# name = mary.rodriguez      domain = riverbend
# name = james.garcia        domain = echovalley
# name = james.garcia        domain = techsparkle
# name = david.brown         domain = echovalley
# name = jessica.thomas      domain = techsparkle
# name = linda.hernandez     domain = echovalley
# name = william.garcia      domain = greengrove
# name = jessica.anderson    domain = bluestream
# name = william.martinez    domain = solarflare
# name = john.moore          domain = quantumbridge
# name = david.johnson       domain = riverbend
# name = elizabeth.williams  domain = bluestream
# name = mary.brown          domain = techsparkle
# name = james.wilson        domain = techsparkle
# name = jessica.wilson      domain = greengrove
# name = william.hernandez   domain = riverbend
# name = susan.thomas        domain = quantumbridge
# name = david.miller        domain = echovalley
# name = jessica.wilson      domain = riverbend
# name = elizabeth.martinez  domain = riverbend
# name = barbara.davis       domain = techsparkle
# name = john.jones          domain = quantumbridge
# name = susan.jones         domain = bluestream
# name = joseph.martinez     domain = quantumbridge
# name = john.garcia         domain = digitaldawn
# name = william.taylor      domain = riverbend
# name = robert.martinez     domain = quantumbridge
# name = jennifer.williams   domain = techsparkle
# name = joseph.williams     domain = techsparkle
# name = patricia.jones      domain = greengrove
# name = david.garcia        domain = techsparkle
# name = barbara.moore       domain = digitaldawn
# name = thomas.williams     domain = greengrove
# name = michael.johnson     domain = greengrove
# name = linda.wilson        domain = quantumbridge
# name = robert.anderson     domain = solarflare
# name = robert.jones        domain = riverbend
# name = thomas.davis        domain = digitaldawn
# name = barbara.williams    domain = techsparkle
# name = john.davis          domain = greengrove
# name = linda.martinez      domain = riverbend
# name = linda.garcia        domain = echovalley
# name = elizabeth.johnson   domain = bluestream
# name = linda.wilson        domain = bluestream
# name = jessica.smith       domain = quantumbridge
# name = susan.williams      domain = bluestream
# name = barbara.garcia      domain = echovalley
# name = joseph.brown        domain = echovalley
# name = michael.johnson     domain = greengrove
# name = susan.jones         domain = digitaldawn
# name = mary.rodriguez      domain = echovalley
# name = john.hernandez      domain = quantumbridge
# name = susan.moore         domain = digitaldawn
# name = michael.johnson     domain = techsparkle
# name = john.garcia         domain = bluestream
# name = susan.taylor        domain = solarflare
# name = mary.thomas         domain = bluestream
# name = john.wilson         domain = techsparkle
# name = william.taylor      domain = riverbend
# name = patricia.jones      domain = greengrove
# name = david.anderson      domain = riverbend
# name = patricia.williams   domain = riverbend
# name = susan.hernandez     domain = quantumbridge
# name = jennifer.rodriguez  domain = riverbend
# name = jennifer.johnson    domain = riverbend
# name = william.rodriguez   domain = echovalley
# name = mary.brown          domain = greengrove
# name = mary.brown          domain = echovalley
# name = thomas.smith        domain = quantumbridge
# name = susan.brown         domain = techsparkle
# name = linda.taylor        domain = bluestream
# name = jennifer.brown      domain = techsparkle
# name = susan.williams      domain = echovalley
# name = michael.brown       domain = quantumbridge
# name = james.martinez      domain = bluestream
# name = robert.davis        domain = bluestream
# name = william.garcia      domain = quantumbridge
# name = michael.thomas      domain = quantumbridge
# name = mary.martinez       domain = echovalley
# name = jennifer.moore      domain = solarflare
# name = john.williams       domain = greengrove
# name = robert.smith        domain = greengrove
# name = patricia.smith      domain = bluestream
# name = patricia.moore      domain = solarflare
# name = susan.jones         domain = echovalley
# name = elizabeth.miller    domain = solarflare
# name = patricia.martinez   domain = solarflare
# name = barbara.martinez    domain = solarflare
# name = joseph.anderson     domain = solarflare
# name = jennifer.thomas     domain = techsparkle
# name = james.johnson       domain = riverbend
# name = robert.anderson     domain = digitaldawn
# name = michael.rodriguez   domain = quantumbridge
# name = patricia.smith      domain = digitaldawn
# name = robert.williams     domain = greengrove
# name = jennifer.jones      domain = riverbend
# name = joseph.miller       domain = echovalley
# name = barbara.martinez    domain = solarflare
# name = barbara.davis       domain = echovalley
# name = james.jones         domain = techsparkle
# name = robert.johnson      domain = bluestream
# name = barbara.thomas      domain = riverbend
# name = barbara.williams    domain = bluestream
# name = john.martinez       domain = riverbend
# name = robert.thomas       domain = techsparkle
# name = jessica.brown       domain = riverbend
# name = michael.wilson      domain = quantumbridge
# name = barbara.jones       domain = echovalley
# name = elizabeth.williams  domain = riverbend
# name = william.moore       domain = bluestream
# name = jessica.wilson      domain = riverbend
# name = mary.garcia         domain = echovalley
# name = william.brown       domain = echovalley
# name = thomas.wilson       domain = echovalley
# name = william.williams    domain = greengrove
# name = michael.rodriguez   domain = greengrove
# name = david.johnson       domain = echovalley
# name = michael.taylor      domain = techsparkle
# name = robert.hernandez    domain = bluestream
# name = william.wilson      domain = echovalley
# name = joseph.davis        domain = echovalley
# name = mary.brown          domain = riverbend
# name = barbara.garcia      domain = riverbend
# name = linda.smith         domain = riverbend
# name = robert.martinez     domain = bluestream
# name = jennifer.taylor     domain = techsparkle
# name = jennifer.brown      domain = techsparkle
# name = david.hernandez     domain = echovalley
# name = barbara.jones       domain = techsparkle
# name = mary.johnson        domain = techsparkle
# name = thomas.smith        domain = bluestream
# name = susan.williams      domain = bluestream
# name = patricia.brown      domain = quantumbridge
# name = susan.martinez      domain = techsparkle
# name = james.miller        domain = techsparkle
# name = james.garcia        domain = digitaldawn
# name = jennifer.taylor     domain = greengrove
# name = linda.rodriguez     domain = echovalley
# name = mary.johnson        domain = quantumbridge
# name = michael.brown       domain = riverbend
# name = william.davis       domain = echovalley
# name = michael.davis       domain = bluestream
# name = linda.martinez      domain = digitaldawn
# name = mary.williams       domain = techsparkle
# name = elizabeth.smith     domain = digitaldawn
# name = john.williams       domain = digitaldawn
# name = susan.taylor        domain = riverbend
# name = linda.brown         domain = solarflare
# name = robert.davis        domain = echovalley
# name = thomas.garcia       domain = solarflare
# name = jennifer.moore      domain = solarflare
# name = linda.williams      domain = techsparkle
# name = jessica.martinez    domain = digitaldawn
# name = barbara.martinez    domain = greengrove
# name = jennifer.taylor     domain = quantumbridge
# name = jessica.garcia      domain = solarflare
# name = patricia.jones      domain = echovalley
# name = barbara.martinez    domain = solarflare
# name = michael.miller      domain = quantumbridge
# name = elizabeth.garcia    domain = bluestream
# name = patricia.taylor     domain = quantumbridge
# name = jennifer.anderson   domain = bluestream
# name = thomas.moore        domain = digitaldawn
# name = john.anderson       domain = echovalley
# name = susan.wilson        domain = quantumbridge
# name = david.rodriguez     domain = echovalley
# name = jessica.davis       domain = quantumbridge
# name = david.wilson        domain = quantumbridge
# name = elizabeth.thomas    domain = techsparkle
# name = susan.taylor        domain = digitaldawn
# name = susan.anderson      domain = greengrove
# name = robert.miller       domain = echovalley
# name = joseph.wilson       domain = digitaldawn
# name = joseph.thomas       domain = quantumbridge
# name = robert.wilson       domain = bluestream

# %% [markdown]
# ## E7.4
# Given the previous email file, count how many emails from each domain are in the list of emails.
#
# Tip: Use the concepts of loops and data structures from previous chapters.

# %%
#emails_format
